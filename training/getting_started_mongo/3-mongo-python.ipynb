# %% [markdown]
# # Getting start with PyMongo

# %% [markdown]
# ## Install the MongoDB python driver PyMongo

# %%
# !pip install  pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Downloading pymongo-4.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (680 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.8/680.8 kB 2.6 MB/s eta 0:00:0000:0100:01
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.0

# %% [markdown]
# ## Import packages

# %%
import os
import pymongo
from pymongo import DESCENDING, ASCENDING
from bson.json_util import dumps

# %% [markdown]
# ## Connection

# %% [markdown]
# #### Before connecting to your Atlas cluster, make sure your loaded sample data into it.
#
# If you didn't, please follow this [tutorial](https://github.com/nosql-esigelec/inge3a_23/blob/main/tp_1/configurations.md#cr%C3%A9er-une-sandbox-ou-bac-%C3%A0-sable).<br>
# After doing it, get your connection string and let's continue.

# %%
# set username, password and host name for your Atlas cluster
# create ENV variables or set directly your username and password
username = os.getenv('USERNAME', 'samuel')
password = os.getenv('USER_PASSWORD', 'esig4GmongoDB')
host = "@cluster0.3cb82pp.mongodb.net"

# %% [markdown]
# `os.getenv` allows you to get environment variables that you set previously. <br>
# The first argument is the name of the variable.<br>
# The second argument is the default value to use if the variable doens't exist

# %%
client = pymongo.MongoClient(f"mongodb+srv://samuel:esig4GmongoDB@cluster0.3cb82pp.mongodb.net/?retryWrites=true&w=majority")

# %%
client.stats
# Out:
# Database(MongoClient(host=['ac-ak5qisr-shard-00-02.3cb82pp.mongodb.net:27017', 'ac-ak5qisr-shard-00-00.3cb82pp.mongodb.net:27017', 'ac-ak5qisr-shard-00-01.3cb82pp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-gbasw5-shard-0', tls=True), 'stats')

# %%
# list the existing databases
client.list_database_names()
# Out:
# ['productDB',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %% [markdown]
# ## CRUD: Create, Read, Update, Delete

# %% [markdown]
# ## Create

# %% [markdown]
# #### Let's connect to database and check data

# %%
product_db = client.productDB

# %%
#print collection names
product_db.list_collection_names()
# Out:
# ['products']

# %%
#store the collection products into a variable
products = product_db.products

# %%
#check one of the data here
products.find_one({})
# Out:
# {'_id': ObjectId('654d21f6b64fad2b7338e84d'),
#  'ProductName': '1 Gallon Soy Milk',
#  'Price': 2.5,
#  'Quantity': 12,
#  'Tags': '["milk","soy"]'}

# %% [markdown]
# #### Inserting data
# Let's add a new product to our store called `Mjöllnir`. It cost `30`€ but don't received it yet so `we don't have any of it` for the moment.

# %%
inserted_product = products.insert_one({"ProductName": "Mjöllir", "Price":30})

# %%
#the attribute aknowleged let us know that the write has been applied in memory 
inserted_product.acknowledged
# Out:
# True

# %%
#after inserting data, we also have an id returned of the object
inserted_product.inserted_id
# Out:
# ObjectId('654d22b0f24c53345a48313a')

# %%
#with this id, I can retrieve the document that I just inserted
products.find_one({"_id": inserted_product.inserted_id})
# Out:
# {'_id': ObjectId('654d22b0f24c53345a48313a'),
#  'ProductName': 'Mjöllir',
#  'Price': 30}

# %% [markdown]
# #### Inserting data from a csv file

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# Lets create a new collection to backup the initial products collection

# %%
products_bup = product_db.products_backup
#make sure that the collection is empty
products_bup.drop()

# %%
#read the csv file as a list of dictionnaries
product_df = pd.read_csv('mongo-data/products.csv', sep=",")
product_df['Tags'] = product_df['Tags'].apply(eval)
product_list = product_df.to_dict(orient="records")
product_list
# Out:
# [{'ProductName': '1 Gallon Soy Milk',
#   'Price': 2.5,
#   'Quantity': 12,
#   'Tags': ['milk', 'soy']},
#  {'ProductName': '1 Gallon Almond Milk',
#   'Price': 2.75,
#   'Quantity': 22,
#   'Tags': ['milk']},
#  {'ProductName': 'Six Pack Soda',
#   'Price': 3.0,
#   'Quantity': 3,
#   'Tags': ['soda', 'pack']},
#  {'ProductName': 'Chocolate Bar',
#   'Price': 1.0,
#   'Quantity': 4,
#   'Tags': ['cacao', 'chocolate']},
#  {'ProductName': 'Paper Towels', 'Price': 1.25, 'Quantity': 8, 'Tags': []},
#  {'ProductName': 'Red Wine',
#   'Price': 14.0,
#   'Quantity': 3,
#   'Tags': ['alcohol', 'wine']},
#  {'ProductName': 'Salt and Vinegar Chips',
#   'Price': 2.25,
#   'Quantity': 22,
#   'Tags': ['salt', 'chips', 'apero']},
#  {'ProductName': 'Barbecue Chips',
#   'Price': 2.25,
#   'Quantity': 1,
#   'Tags': ['apero', 'chips']},
#  {'ProductName': 'Gatorade', 'Price': 2.0, 'Quantity': 21, 'Tags': []},
#  {'ProductName': 'Breath Mints', 'Price': 0.5, 'Quantity': 11, 'Tags': []}]

# %%
products_bup.insert_many(product_list)
# Out:
# InsertManyResult([ObjectId('654d249df24c53345a48313b'), ObjectId('654d249df24c53345a48313c'), ObjectId('654d249df24c53345a48313d'), ObjectId('654d249df24c53345a48313e'), ObjectId('654d249df24c53345a48313f'), ObjectId('654d249df24c53345a483140'), ObjectId('654d249df24c53345a483141'), ObjectId('654d249df24c53345a483142'), ObjectId('654d249df24c53345a483143'), ObjectId('654d249df24c53345a483144')], acknowledged=True)

# %%
print(dumps(products_bup.find_one({}), indent=2))
# Out:
# {
#   "_id": {
#     "$oid": "654d249df24c53345a48313b"
#   },
#   "ProductName": "1 Gallon Soy Milk",
#   "Price": 2.5,
#   "Quantity": 12,
#   "Tags": [
#     "milk",
#     "soy"
#   ]
# }

# %% [markdown]
# ## Update

# %% [markdown]
# #### Updating data
# We just received the products and we noticed that we put a wring name at the insertion of data. Let's update the document of this product.

# %%
#create a document with values to update/add
mjollnir = {"ProductName": "Mjöllnir", "Quantity":100}

# %%
update_result = products.update_one({"ProductName": "Mjöllir"},{"$set":mjollnir})
print(f"Number of documents: {products.count_documents({})}")
print(update_result.raw_result)
# Out:
# Number of documents: 11
# {'n': 1, 'electionId': ObjectId('7fffffff0000000000000083'), 'opTime': {'ts': Timestamp(1699555878, 2), 't': 131}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699555878, 2), 'signature': {'hash': b'>>\xbc\xa0w\xa1\xd3\xa7(\x14E[\x19\xbc\xc5\xb3\xaf\xcf0\x88', 'keyId': 7254600221399711745}}, 'operationTime': Timestamp(1699555878, 2), 'updatedExisting': True}

# %% [markdown]
# #### Upserting data
# Upsert is inserting data if not filter is doesn't find a match.<br>
# Let's take an example with a new product.

# %%
#creating a document for stormbreaker
stormbreaker = {"ProductName": "Stormbreaker", "price":50, "Quantity":100}

# %%
stormbreaker_update = products.update_one({"ProductName": "Stormbreaker"},{"$set":stormbreaker})
print(f"Number of documents: {products.count_documents({})}")
print(stormbreaker_update.raw_result)
# Out:
# Number of documents: 11
# {'n': 0, 'electionId': ObjectId('7fffffff0000000000000083'), 'opTime': {'ts': Timestamp(1699556152, 1), 't': 131}, 'nModified': 0, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699556152, 1), 'signature': {'hash': b'=\xb7\x96\xafB\xf3\xb2\xee\xc0c-\xc9\xad{\xf1\xcb\\I\xb3\xc8', 'keyId': 7254600221399711745}}, 'operationTime': Timestamp(1699556152, 1), 'updatedExisting': False}

# %% [markdown]
# The number of documents didn't changed from the last time.
# Nothing happened in the update because this product doen't exist. In some case, we would like to insert the document if it doesn't exist. That's why we can use the attribute `upsert`.

# %%
stormbreaker_update = products.update_one({"ProductName": "Stormbreaker"},{"$set":stormbreaker}, 
                                          upsert=True)
print(f"Number of documents: {products.count_documents({})}")
print(stormbreaker_update.raw_result)
# Out:
# Number of documents: 12
# {'n': 1, 'electionId': ObjectId('7fffffff0000000000000083'), 'opTime': {'ts': Timestamp(1699556913, 7), 't': 131}, 'upserted': ObjectId('654d2e31e141662f4e259ba0'), 'nModified': 0, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699556913, 7), 'signature': {'hash': b'-\xf4\xe0\xacV\xf7o\xceg\x16\xe2\x08\xe6\xba\xa2c\xf5\xf5\xf4^', 'keyId': 7254600221399711745}}, 'operationTime': Timestamp(1699556913, 7), 'updatedExisting': False}

# %% [markdown]
# The number of documents increased. In fact the non-existing document has been inserted.

# %% [markdown]
# #### Updating some informations on products
#
# - **Numerical attribute**
#
# Let's say we want to add increase the quantity of a product with 10 units

# %%
product_filter = {"ProductName": "1 Gallon Soy Milk"}

# %%
products_bup.update_one(product_filter, {"$inc": {"Quantity":10}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000083'), 'opTime': {'ts': Timestamp(1699557321, 2), 't': 131}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699557321, 2), 'signature': {'hash': b"]\xde2\x05\xfcez\xef\x9c\x1f^\x0c\x8c\xa9s7}'0\xd2", 'keyId': 7254600221399711745}}, 'operationTime': Timestamp(1699557321, 2), 'updatedExisting': True}, acknowledged=True)

# %%
print(dumps(products_bup.find_one(product_filter), indent=2))
# Out:
# {
#   "_id": {
#     "$oid": "654d249df24c53345a48313b"
#   },
#   "ProductName": "1 Gallon Soy Milk",
#   "Price": 2.5,
#   "Quantity": 22,
#   "Tags": [
#     "milk",
#     "soy"
#   ]
# }

# %% [markdown]
# - **Array attribute** (add an item to an **existing** array)
#
# We'll use the product "Red Wine for this example.

# %%
red_wine = {"ProductName": "Red Wine"}

# %% [markdown]
# Let's add a tag on it

# %%
products_bup.update_one(red_wine, {"$push": {"Tags": "Happiness"}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000083'), 'opTime': {'ts': Timestamp(1699557508, 7), 't': 131}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699557508, 7), 'signature': {'hash': b'q8\xdb\xd7\xe7\xd7\x1f\xb7\xcc N%\x8c\xc8\x15\xe4\xc1\xaaY\x99', 'keyId': 7254600221399711745}}, 'operationTime': Timestamp(1699557508, 7), 'updatedExisting': True}, acknowledged=True)

# %%
print(dumps(products_bup.find_one(red_wine), indent=2))
# Out:
# {
#   "_id": {
#     "$oid": "654d249df24c53345a483140"
#   },
#   "ProductName": "Red Wine",
#   "Price": 14.0,
#   "Quantity": 3,
#   "Tags": [
#     "alcohol",
#     "wine",
#     "Happiness"
#   ]
# }

# %% [markdown]
# - **Array attribute** (add an item to an **non-existing** array)
#
# We would like to add warning about some products like alocohol

# %%
products_bup.update_one(red_wine, {"$push": {"Warnings": "Prohibited under 18"}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000083'), 'opTime': {'ts': Timestamp(1699557754, 13), 't': 131}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699557754, 13), 'signature': {'hash': b'\xe8\xa6\xd2wuc\xac&\xf7:\x88\xba\xbd\xe6s\x06dY V', 'keyId': 7254600221399711745}}, 'operationTime': Timestamp(1699557754, 13), 'updatedExisting': True}, acknowledged=True)

# %%
print(dumps(products_bup.find_one(red_wine), indent=2))
# Out:
# {
#   "_id": {
#     "$oid": "654d249df24c53345a483140"
#   },
#   "ProductName": "Red Wine",
#   "Price": 14.0,
#   "Quantity": 3,
#   "Tags": [
#     "alcohol",
#     "wine",
#     "Happiness"
#   ],
#   "Warnings": [
#     "Prohibited under 18"
#   ]
# }

# %%
#Let's say we would like to add an arrival date to all products
arrival_update = products_bup.update_many({}, {"$set":{"ArrivalDate": datetime.datetime.now()}})

# %%
print(dumps(products_bup.find({}, {"_id":0,"ProductName":1, "ArrivalDate":1}), indent=2))
# Out:
# [
#   {
#     "ProductName": "1 Gallon Soy Milk",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "1 Gallon Almond Milk",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "Six Pack Soda",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "Chocolate Bar",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "Paper Towels",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "Red Wine",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "Salt and Vinegar Chips",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "Barbecue Chips",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "Gatorade",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   },
#   {
#     "ProductName": "Breath Mints",
#     "ArrivalDate": {
#       "$date": "2023-11-09T19:07:13.585Z"
#     }
#   }
# ]

# %%
print(f"Acknowledge: {arrival_update.acknowledged}")
print(f"Mached Count: {arrival_update.matched_count}")
print(f"Modified Count: {arrival_update.modified_count}")
print(f"Upserted Id: {arrival_update.upserted_id}")
# Out:
# Acknowledge: True
# Mached Count: 10
# Modified Count: 10
# Upserted Id: None

# %% [markdown]
# ## Delete

# %% [markdown]
# Let's delete a specific product.

# %%
product_filter = {"ProductName": "Gatorade"}
print(f"Before Delete: The number of products is {len(list(products_bup.find(product_filter)))}")
products_bup.delete_one(product_filter)
print(f"After Delete: The number of products is {len(list(products_bup.find(product_filter)))}")
# Out:
# Before Delete: The number of products is 1
# After Delete: The number of products is 0

# %% [markdown]
# We'll use products that have less than 10 items for our example.

# %%
product_to_delete = {"Quantity": {"$lte":10}}

# %% [markdown]
# Let's delete the first product matching this condition.<br>
# We can use the attribute deleted_count to check the number of deleted items.

# %%
print(f"Before Delete: The number of products is {len(list(products_bup.find(product_to_delete)))}")
delete_one_operation = products_bup.delete_one(product_to_delete)
print(f"After Delete: The number of products is {len(list(products_bup.find(product_to_delete)))}")
print(f"The number of documents deleted is {delete_one_operation.deleted_count}")
# Out:
# Before Delete: The number of products is 5
# After Delete: The number of products is 4
# The number of documents deleted is 1

# %%
print(f"Before Delete: The number of products is {len(list(products_bup.find(product_to_delete)))}")
delete_many_operation = products_bup.delete_many(product_to_delete)
print(f"After Delete: The number of products is {len(list(products_bup.find(product_to_delete)))}")
print(f"The number of documents deleted is {delete_many_operation.deleted_count}")
# Out:
# Before Delete: The number of products is 4
# After Delete: The number of products is 0
# The number of documents deleted is 4

# %% [markdown]
# ## Read

# %% [markdown]
# #### Let's connect to database and check data

# %%
mflix_db = client.sample_mflix

# %%
# list the existing collections in MFlix
mflix_db.list_collection_names()
# Out:
# ['embedded_movies', 'users', 'comments', 'theaters', 'sessions', 'movies']

# %%
movies = mflix_db.movies

# %%
movies.count_documents({})
# Out:
# 21349

# %% [markdown]
# ### First operations
#
# - Reading with find_one()
# - Reading with find
#     - Iterating through cursors
# - Field projection and filtering

# %%
# find one movie record
movies.find_one({})
# Out:
# {'_id': ObjectId('573a1390f29313caabcd42e8'),
#  'plot': 'A group of bandits stage a brazen train hold-up, only to find a determined posse hot on their heels.',
#  'genres': ['Short', 'Western'],
#  'runtime': 11,
#  'cast': ['A.C. Abadie',
#   "Gilbert M. 'Broncho Billy' Anderson",
#   'George Barnes',
#   'Justus D. Barnes'],
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU3NjE5NzYtYTYyNS00MDVmLWIwYjgtMmYwYWIxZDYyNzU2XkEyXkFqcGdeQXVyNzQzNzQxNzI@._V1_SY1000_SX677_AL_.jpg',
#  'title': 'The Great Train Robbery',
#  'fullplot': "Among the earliest existing films in American cinema - notable as the first film that presented a narrative story to tell - it depicts a group of cowboy outlaws who hold up a train and rob the passengers. They are then pursued by a Sheriff's posse. Several scenes have color included - all hand tinted.",
#  'languages': ['English'],
#  'released': datetime.datetime(1903, 12, 1, 0, 0),
#  'directors': ['Edwin S. Porter'],
#  'rated': 'TV-G',
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-08-13 00:27:59.177000000',
#  'year': 1903,
#  'imdb': {'rating': 7.4, 'votes': 9847, 'id': 439},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 2559, 'meter': 75},
#   'fresh': 6,
#   'critic': {'rating': 7.6, 'numReviews': 6, 'meter': 100},
#   'rotten': 0,
#   'lastUpdated': datetime.datetime(2015, 8, 8, 19, 16, 10)},
#  'num_mflix_comments': 0}

# %%
# find one movie record with Salma Hayek as an actor
movies.find_one({"cast": "Salma Hayek"})
# Out:
# {'_id': ObjectId('573a1399f29313caabceea6d'),
#  'plot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'genres': ['Action', 'Drama'],
#  'runtime': 95,
#  'rated': 'R',
#  'cast': ['David Arquette', 'John Hawkes', 'Salma Hayek', 'Jason Wiles'],
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'title': 'Roadracers',
#  'fullplot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'languages': ['English'],
#  'released': datetime.datetime(1994, 7, 22, 0, 0),
#  'directors': ['Robert Rodriguez'],
#  'writers': ['Robert Rodriguez', 'Tommy Nix'],
#  'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#  'lastupdated': '2015-09-01 00:53:54.567000000',
#  'year': 1994,
#  'imdb': {'rating': 6.7, 'votes': 2036, 'id': 111002},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 7487, 'meter': 31},
#   'dvd': datetime.datetime(2002, 9, 3, 0, 0),
#   'critic': {'rating': 4.9, 'numReviews': 23, 'meter': 26},
#   'lastUpdated': datetime.datetime(2015, 9, 11, 18, 0, 30),
#   'rotten': 17,
#   'production': 'Hollywood Pictures',
#   'fresh': 6}}

# %%
# display the movies in which Salma Hayek acted
salma = movies.find({"cast": "Salma Hayek"})
print(dumps(salma, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabceea6d"
#     },
#     "plot": "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#     "genres": [
#       "Action",
#       "Drama"
#     ],
#     "runtime": 95,
#     "rated": "R",
#     "cast": [
#       "David Arquette",
#       "John Hawkes",
#       "Salma Hayek",
#       "Jason Wiles"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Roadracers",
#     "fullplot": "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1994-07-22T00:00:00Z"
#     },
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "writers": [
#       "Robert Rodriguez",
#       "Tommy Nix"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-09-01 00:53:54.567000000",
#     "year": 1994,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 2036,
#       "id": 111002
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 7487,
#         "meter": 31
#       },
#       "dvd": {
#         "$date": "2002-09-03T00:00:00Z"
#       },
#       "critic": {
#         "rating": 4.9,
#         "numReviews": 23,
#         "meter": 26
#       },
#       "lastUpdated": {
#         "$date": "2015-09-11T18:00:30Z"
#       },
#       "rotten": 17,
#       "production": "Hollywood Pictures",
#       "fresh": 6
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef179"
#     },
#     "fullplot": "With this sequel to his prize-winning independent previous film, \"El Mariachi,\" director Robert Rodriquez joins the ranks of Sam Peckinpah and John Woo as a master of slick, glamorized ultra-violence. We pick up the story as a continuation of \"El Mariachi,\" where an itinerant musician, looking for work, gets mistaken for a hitman and thereby entangled in a web of love, corruption, and death. This time, he is out to avenge the murder of his lover and the maiming of his fretting hand, which occurred at the end of the earlier movie. However, the plot is recapitulated, and again, a case of mistaken identity leads to a very high body count, involvement with a beautiful woman who works for the local drug lord, and finally, the inevitable face-to-face confrontation and bloody showdown.",
#     "imdb": {
#       "rating": 7.2,
#       "votes": 127966,
#       "id": 112851
#     },
#     "year": 1995,
#     "plot": "A gunslinger is embroiled in a war with a local drug runner.",
#     "genres": [
#       "Action",
#       "Crime",
#       "Thriller"
#     ],
#     "rated": "R",
#     "metacritic": 55,
#     "title": "Desperado",
#     "lastupdated": "2015-08-29 00:25:05.467000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Robert Rodriguez"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.5,
#         "numReviews": 187644,
#         "meter": 80
#       },
#       "dvd": {
#         "$date": "1997-06-25T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.4,
#         "numReviews": 39,
#         "meter": 62
#       },
#       "lastUpdated": {
#         "$date": "2015-09-13T17:30:57Z"
#       },
#       "rotten": 15,
#       "production": "Sony Pictures Home Entertainment",
#       "fresh": 24
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYjA0NDMyYTgtMDgxOC00NGE0LWJkOTQtNDRjMjEzZmU0ZTQ3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 0,
#     "released": {
#       "$date": "1995-08-25T00:00:00Z"
#     },
#     "awards": {
#       "wins": 0,
#       "nominations": 4,
#       "text": "4 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Joaquim de Almeida",
#       "Cheech Marin"
#     ],
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "runtime": 104
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf092d"
#     },
#     "plot": "After a one night stand with Isabel, Alex realizes that she is pregnant and they decide to get married. However, along with the marriage comes compromise of one's own cultural traditions.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 109,
#     "metacritic": 37,
#     "rated": "PG-13",
#     "cast": [
#       "Matthew Perry",
#       "Salma Hayek",
#       "Jon Tenney",
#       "Carlos G\u00e8mez"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BM2Q3MzA3YmYtNzUzNS00NDhhLTkyZmYtMDU2YmE1ODY5MjdmXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Fools Rush In",
#     "fullplot": "Sparks fly and cultures collide in this romantic comedy about a casual night of passion that turns into the love of a lifetime. Alex Whitman is a New Yorker sent to Las Vegas to oversee a construction project. There he meets Isabel Fuentes, and some serious chemistry brings them together for one night. But Alex doesn't see Isabel again until three months later, when he learns she is pregnant. On a whim and prayer, he proposes. However, there's more to marriage than a Vegas chapel and an Elvis impersonator, as Alex and Isabel soon learn.",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": "1997-02-14T00:00:00Z"
#     },
#     "directors": [
#       "Andy Tennant"
#     ],
#     "writers": [
#       "Joan Taylor (story)",
#       "Katherine Reback (story)",
#       "Katherine Reback (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 2,
#       "text": "2 nominations."
#     },
#     "lastupdated": "2015-09-07 00:52:44.310000000",
#     "year": 1997,
#     "imdb": {
#       "rating": 6.0,
#       "votes": 26104,
#       "id": 119141
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.0,
#         "numReviews": 62870,
#         "meter": 64
#       },
#       "dvd": {
#         "$date": "1998-02-10T00:00:00Z"
#       },
#       "critic": {
#         "rating": 4.8,
#         "numReviews": 27,
#         "meter": 33
#       },
#       "lastUpdated": {
#         "$date": "2015-08-18T18:51:54Z"
#       },
#       "rotten": 18,
#       "production": "Sony Pictures Home Entertainment",
#       "fresh": 9
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf09f1"
#     },
#     "plot": "Based on the novel, a young gypsy becomes a Minister's obsession in 1483. Only the bell ringer and her husband and the court of miracles can save her.",
#     "genres": [
#       "Drama",
#       "Horror",
#       "Romance"
#     ],
#     "runtime": 98,
#     "cast": [
#       "Mandy Patinkin",
#       "Richard Harris",
#       "Salma Hayek",
#       "Edward Atterton"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTMxNTk1MTEyNV5BMl5BanBnXkFtZTcwMDk3MjYyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "The Hunchback",
#     "fullplot": "Based on the novel, a young gypsy becomes a Minister's obsession in 1483. Only the bell ringer and her husband and the court of miracles can save her.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1997-03-16T00:00:00Z"
#     },
#     "directors": [
#       "Peter Medak"
#     ],
#     "writers": [
#       "Victor Hugo (novel)",
#       "John Fasano (teleplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 12,
#       "text": "Nominated for 4 Primetime Emmys. Another 8 nominations."
#     },
#     "lastupdated": "2015-08-12 00:16:56.157000000",
#     "year": 1997,
#     "imdb": {
#       "rating": 6.2,
#       "votes": 1129,
#       "id": 119329
#     },
#     "countries": [
#       "USA",
#       "Hungary",
#       "Canada",
#       "Czech Republic"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 2.9,
#         "numReviews": 50,
#         "meter": 39
#       },
#       "dvd": {
#         "$date": "1998-05-19T00:00:00Z"
#       },
#       "lastUpdated": {
#         "$date": "2015-07-31T18:05:19Z"
#       }
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0e4f"
#     },
#     "plot": "Famous 70s NYC nightclub seen and told through the eyes of a young employee.",
#     "genres": [
#       "Drama",
#       "Music"
#     ],
#     "runtime": 93,
#     "metacritic": 33,
#     "rated": "R",
#     "cast": [
#       "Ryan Phillippe",
#       "Salma Hayek",
#       "Neve Campbell",
#       "Mike Myers"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIzNzIxMjEtZDNiZS00Y2E1LTkwOTItZGJjOTMwYzU4YzVmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SY1000_SX677_AL_.jpg",
#     "title": "54",
#     "lastupdated": "2015-09-16 12:22:02.100000000",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1998-08-28T00:00:00Z"
#     },
#     "directors": [
#       "Mark Christopher"
#     ],
#     "writers": [
#       "Mark Christopher"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 7,
#       "text": "7 nominations."
#     },
#     "year": 1998,
#     "imdb": {
#       "rating": 5.8,
#       "votes": 26612,
#       "id": 120577
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/movie/54",
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 31237,
#         "meter": 44
#       },
#       "dvd": {
#         "$date": "2001-04-03T00:00:00Z"
#       },
#       "critic": {
#         "rating": 4.2,
#         "numReviews": 66,
#         "meter": 15
#       },
#       "lastUpdated": {
#         "$date": "2015-08-22T19:09:51Z"
#       },
#       "consensus": "Poor plot development and slow pacing keep 54 from capturing the energy of it's legendary namesake.",
#       "rotten": 56,
#       "production": "Miramax Films",
#       "fresh": 10
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0ea6"
#     },
#     "fullplot": "\"Frida\" chronicles the life Frida Kahlo shared unflinchingly and openly with Diego Rivera, as the young couple took the art world by storm. From her complex and enduring relationship with her mentor and husband to her illicit and controversial affair with Leon Trotsky, to her provocative and romantic entanglements with women, Frida Kahlo lived a bold and uncompromising life as a political, artistic, and sexual revolutionary.",
#     "imdb": {
#       "rating": 7.4,
#       "votes": 57256,
#       "id": 120679
#     },
#     "year": 2002,
#     "plot": "A biography of artist Frida Kahlo, who channeled the pain of a crippling injury and her tempestuous marriage into her work.",
#     "genres": [
#       "Biography",
#       "Drama",
#       "Romance"
#     ],
#     "rated": "R",
#     "metacritic": 61,
#     "title": "Frida",
#     "lastupdated": "2015-09-12 00:33:36.510000000",
#     "languages": [
#       "English",
#       "French",
#       "Russian"
#     ],
#     "writers": [
#       "Hayden Herrera (book)",
#       "Clancy Sigal (screenplay)",
#       "Diane Lake (screenplay)",
#       "Gregory Nava (screenplay)",
#       "Anna Thomas (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/frida/",
#       "viewer": {
#         "rating": 3.7,
#         "numReviews": 53261,
#         "meter": 86
#       },
#       "dvd": {
#         "$date": "2003-06-10T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.9,
#         "numReviews": 151,
#         "meter": 76
#       },
#       "boxOffice": "$25.7M",
#       "consensus": "Frida is a passionate, visually striking biopic about the larger-than-life artist.",
#       "rotten": 36,
#       "production": "Miramax Films",
#       "lastUpdated": {
#         "$date": "2015-09-13T18:08:34Z"
#       },
#       "fresh": 115
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYzUxMTU0ZmEtZWE0Ni00NzJlLThhZTUtNDA1ZDZjZDUxYThiXkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 1,
#     "released": {
#       "$date": "2002-11-22T00:00:00Z"
#     },
#     "awards": {
#       "wins": 19,
#       "nominations": 33,
#       "text": "Won 2 Oscars. Another 17 wins & 33 nominations."
#     },
#     "countries": [
#       "USA",
#       "Canada",
#       "Mexico"
#     ],
#     "cast": [
#       "Salma Hayek",
#       "M\u00e8a Maestro",
#       "Alfred Molina",
#       "Antonio Banderas"
#     ],
#     "directors": [
#       "Julie Taymor"
#     ],
#     "runtime": 123
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0f48"
#     },
#     "fullplot": "Jim West is a guns-a-blazing former Civil War hero. Artemus Gordon is an inventive U.S. Marshal who excels in disguise. When the United States is threatened by psychotic Confederate Arliss Loveless, President Ulysses Grant teams the duo up to bring him to justice. On a hazard-packed train journey from Washington D.C. to Utah, West and Gordon must combine their skills to best Loveless and his diabolical machines.",
#     "imdb": {
#       "rating": 4.8,
#       "votes": 122655,
#       "id": 120891
#     },
#     "year": 1999,
#     "plot": "The two best hired guns in the West must save President Grant from the clutches of a nineteenth-century inventor-villain.",
#     "genres": [
#       "Action",
#       "Western",
#       "Comedy"
#     ],
#     "rated": "PG-13",
#     "metacritic": 38,
#     "title": "Wild Wild West",
#     "lastupdated": "2015-09-10 17:48:40.287000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Jim Thomas (story)",
#       "John Thomas (story)",
#       "S.S. Wilson (screenplay)",
#       "Brent Maddock (screenplay)",
#       "Jeffrey Price (screenplay)",
#       "Peter S. Seaman (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://wildwildwest.warnerbros.com",
#       "viewer": {
#         "rating": 2.7,
#         "numReviews": 463636,
#         "meter": 28
#       },
#       "dvd": {
#         "$date": "1999-11-30T00:00:00Z"
#       },
#       "critic": {
#         "rating": 4.1,
#         "numReviews": 130,
#         "meter": 17
#       },
#       "lastUpdated": {
#         "$date": "2015-09-12T18:14:42Z"
#       },
#       "consensus": "Bombastic, manic, and largely laugh-free, Wild Wild West is a bizarre misfire in which greater care was lavished upon the special effects than on the script.",
#       "rotten": 108,
#       "production": "Warner Bros. Pictures",
#       "fresh": 22
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYmYyMTc4YjItMGNhNC00OWQwLWJhMWUtNTdjZDgxMDI5MjE2L2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 1,
#     "released": {
#       "$date": "1999-06-30T00:00:00Z"
#     },
#     "awards": {
#       "wins": 10,
#       "nominations": 11,
#       "text": "10 wins & 11 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Will Smith",
#       "Kevin Kline",
#       "Kenneth Branagh",
#       "Salma Hayek"
#     ],
#     "directors": [
#       "Barry Sonnenfeld"
#     ],
#     "runtime": 106
#   },
#   {
#     "_id": {
#       "$oid": "573a139bf29313caabcf3c57"
#     },
#     "plot": "Every Friday, the Colonel puts on his only suit and goes to the dock to await a letter announcing the arrival of his pension. But the townsfolk all know that this pension will never come. ...",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 118,
#     "cast": [
#       "Fernando Luj\u00e8n",
#       "Marisa Paredes",
#       "Salma Hayek",
#       "Rafael Incl\u00e8n"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTQxNjc2Njk1NV5BMl5BanBnXkFtZTcwOTY2MTU1MQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "No One Writes to the Colonel",
#     "fullplot": "Every Friday, the Colonel puts on his only suit and goes to the dock to await a letter announcing the arrival of his pension. But the townsfolk all know that this pension will never come. His wife also knows it, and even he knows it. But he is still waiting, living with the pain of the death of his son.",
#     "languages": [
#       "Spanish"
#     ],
#     "released": {
#       "$date": "1999-06-02T00:00:00Z"
#     },
#     "directors": [
#       "Arturo Ripstein"
#     ],
#     "writers": [
#       "Paz Alicia Garciadiego",
#       "Gabriel Garc\u00e8a M\u00e8rquez (novel)"
#     ],
#     "awards": {
#       "wins": 1,
#       "nominations": 2,
#       "text": "1 win & 2 nominations."
#     },
#     "lastupdated": "2015-07-30 00:34:51.927000000",
#     "year": 1999,
#     "imdb": {
#       "rating": 6.9,
#       "votes": 821,
#       "id": 132905
#     },
#     "countries": [
#       "Mexico",
#       "France",
#       "Spain"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.3,
#         "numReviews": 1004,
#         "meter": 62
#       },
#       "dvd": {
#         "$date": "2003-06-10T00:00:00Z"
#       },
#       "production": "Latin Crush",
#       "lastUpdated": {
#         "$date": "2015-09-12T19:21:42Z"
#       }
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a139ef29313caabcfba16"
#     },
#     "fullplot": "An anthology film retelling the story of the famous Studio 54, a hot disco hangout for the social elite of New York. The movie follows several characters at once, some of whom are in desperate straits and on the verge of crashing.",
#     "imdb": {
#       "rating": 5.8,
#       "votes": 26552,
#       "id": 120577
#     },
#     "year": 1998,
#     "plot": "Famous 70s NYC nightclub seen and told through the eyes of a young employee.",
#     "genres": [
#       "Drama",
#       "Music"
#     ],
#     "rated": "R",
#     "metacritic": 33,
#     "title": "54",
#     "lastupdated": "2015-08-30 02:17:08.113000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Mark Christopher"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/movie/54",
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 31237,
#         "meter": 44
#       },
#       "dvd": {
#         "$date": "2001-04-03T00:00:00Z"
#       },
#       "critic": {
#         "rating": 4.2,
#         "numReviews": 66,
#         "meter": 15
#       },
#       "lastUpdated": {
#         "$date": "2015-08-22T19:09:51Z"
#       },
#       "consensus": "Poor plot development and slow pacing keep 54 from capturing the energy of it's legendary namesake.",
#       "rotten": 56,
#       "production": "Miramax Films",
#       "fresh": 10
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIzNzIxMjEtZDNiZS00Y2E1LTkwOTItZGJjOTMwYzU4YzVmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 0,
#     "released": {
#       "$date": "1998-08-28T00:00:00Z"
#     },
#     "awards": {
#       "wins": 0,
#       "nominations": 7,
#       "text": "7 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Ryan Phillippe",
#       "Salma Hayek",
#       "Neve Campbell",
#       "Mike Myers"
#     ],
#     "directors": [
#       "Mark Christopher"
#     ],
#     "runtime": 93
#   },
#   {
#     "_id": {
#       "$oid": "573a13a4f29313caabd1276d"
#     },
#     "plot": "In the Time of the Butterflies is inspired by the true story of the three Mirabal sisters who, in 1960, were murdered for their part in an underground plot to overthrow the government.",
#     "genres": [
#       "Crime",
#       "Drama",
#       "History"
#     ],
#     "runtime": 95,
#     "rated": "PG-13",
#     "cast": [
#       "Salma Hayek",
#       "Edward James Olmos",
#       "M\u00e8a Maestro",
#       "Demian Bichir"
#     ],
#     "num_mflix_comments": 0,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTQyNzc0NDExN15BMl5BanBnXkFtZTcwOTYwOTAyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "In the Time of the Butterflies",
#     "fullplot": "On November 25, 1960, the bodies of three sisters were found near the bottom of a cliff on the north coast of the Dominican Republic. The official daily 'El Caribe' reports that it had been an accident, but it does not mention that a fourth sister lives. Nor does it mention the sisters' fierce opposition to the General Trujillo's dictatorship. This is their story: how Minerva started the tragedy by refusing Trujillo; how Patria became an opponent from the church itself; how Maria Teresa joined the revolution through the love. And how they lost their wings, but not their courage. They were Las Mariposas - \"The Butterflies\".",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2004-08-19T00:00:00Z"
#     },
#     "directors": [
#       "Mariano Barroso"
#     ],
#     "writers": [
#       "Julia \u00e8lvarez (novel)",
#       "Judy Klass (teleplay)",
#       "David Klass (teleplay)"
#     ],
#     "awards": {
#       "wins": 2,
#       "nominations": 2,
#       "text": "2 wins & 2 nominations."
#     },
#     "lastupdated": "2015-08-28 00:32:45.503000000",
#     "year": 2001,
#     "imdb": {
#       "rating": 6.8,
#       "votes": 1648,
#       "id": 263467
#     },
#     "countries": [
#       "USA",
#       "Mexico"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.8,
#         "numReviews": 3826,
#         "meter": 78
#       },
#       "dvd": {
#         "$date": "2002-05-07T00:00:00Z"
#       },
#       "production": "MGM",
#       "lastUpdated": {
#         "$date": "2015-07-21T18:53:16Z"
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13a6f29313caabd17bd5"
#     },
#     "fullplot": "In the third movie of Rodriguez's \"Mariachi\" trilogy, a Mexican drug lord pretends to overthrow the Mexican government, and is connected to a corrupt CIA agent who at that time, demands retribution from his worst enemy to carry out the drug lord's uprising against the government.",
#     "imdb": {
#       "rating": 6.4,
#       "votes": 122029,
#       "id": 285823
#     },
#     "year": 2003,
#     "plot": "Hitman \"El Mariachi\" becomes involved in international espionage involving a psychotic CIA agent and a corrupt Mexican general.",
#     "genres": [
#       "Action",
#       "Thriller"
#     ],
#     "rated": "R",
#     "metacritic": 56,
#     "title": "Once Upon a Time in Mexico",
#     "lastupdated": "2015-09-07 00:09:02.457000000",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "writers": [
#       "Robert Rodriguez"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.sonypictures.com/movies/onceuponatimeinmexico/",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 284917,
#         "meter": 64
#       },
#       "dvd": {
#         "$date": "2004-01-20T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.3,
#         "numReviews": 163,
#         "meter": 68
#       },
#       "boxOffice": "$55.8M",
#       "consensus": "Violent, pulpy, loopy fun, with Depp stealing the show.",
#       "rotten": 52,
#       "production": "Sony Pictures Releasing",
#       "lastUpdated": {
#         "$date": "2015-09-14T18:03:16Z"
#       },
#       "fresh": 111
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTU5MDg5OTcwOV5BMl5BanBnXkFtZTcwMjI1MTIzMw@@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 0,
#     "released": {
#       "$date": "2003-09-12T00:00:00Z"
#     },
#     "awards": {
#       "wins": 3,
#       "nominations": 4,
#       "text": "3 wins & 4 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Johnny Depp",
#       "Mickey Rourke"
#     ],
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "runtime": 102
#   },
#   {
#     "_id": {
#       "$oid": "573a13adf29313caabd2af88"
#     },
#     "plot": "The story of what happens after a master thief achieves his last big score, when the FBI agent who promised he'd capture him is about to do just that.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Crime"
#     ],
#     "runtime": 97,
#     "metacritic": 38,
#     "rated": "PG-13",
#     "cast": [
#       "Pierce Brosnan",
#       "Salma Hayek",
#       "Woody Harrelson",
#       "Don Cheadle"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BN2YyMmE1MTUtNTg2OS00ZWRiLWFhZTQtZDViM2MyOGJhZDY3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "title": "After the Sunset",
#     "fullplot": "After a successful last score, a master thief retires to an island paradise. His lifelong nemesis, a crafty FBI agent, washes ashore to ensure he's making good on his promise. The pair soon enters into a new game of cat-and-mouse.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2004-11-12T00:00:00Z"
#     },
#     "directors": [
#       "Brett Ratner"
#     ],
#     "writers": [
#       "Paul Zbyszewski (story)",
#       "Paul Zbyszewski (screenplay)",
#       "Craig Rosenberg (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-21 00:50:02.187000000",
#     "year": 2004,
#     "imdb": {
#       "rating": 6.3,
#       "votes": 36636,
#       "id": 367479
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a13aff29313caabd2f0a5"
#     },
#     "plot": "Mexican beauty Camilla hopes to rise above her station by marrying a wealthy American. That is complicated by meeting Arturo Bandini, a first-generation Italian hoping to land a writing career and a blue-eyed blonde on his arm.",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 117,
#     "metacritic": 58,
#     "rated": "R",
#     "cast": [
#       "Colin Farrell",
#       "Salma Hayek",
#       "Donald Sutherland",
#       "Eileen Atkins"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BZDc0ZWFmYjAtMTc2ZS00MzdlLThkZjAtM2I5ZGZlZjYzZDRlXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Ask the Dust",
#     "fullplot": "L.A. in the early 1930's: racism, poverty, and disease color the Bunker Hill neighborhood where Arturo Bandini, a lover of men and beasts alike, has arrived from Colorado to write the great Los Angeles novel. After six months and down to his last nickel, he orders a cup of coffee, served by Camilla Lopez, beautiful, self-possessed, and Mexican. Arturo gets advice, encouragement, and an occasional check from H.L. Mencken, so he keeps writing and he keeps seeing Camilla. But, he's mean to her for no apparent reason, so the relationship sputters. A housekeeper from back East suggests a way out of his jealously and fears. \"Camilla Bandini\": is it in the cards?",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": "2006-04-13T00:00:00Z"
#     },
#     "directors": [
#       "Robert Towne"
#     ],
#     "writers": [
#       "Robert Towne (screenplay)",
#       "John Fante (novel)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-14 01:31:42.053000000",
#     "year": 2006,
#     "imdb": {
#       "rating": 5.8,
#       "votes": 7690,
#       "id": 384814
#     },
#     "countries": [
#       "USA",
#       "Germany"
#     ],
#     "type": "movie",
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3c2c0"
#     },
#     "plot": "Based on the true story, two homicide detectives track Martha Beck and Raymond Martinez Fernandez, a murderous pair known as the \"Lonely Hearts Killers\" who lured their victims through the personals.",
#     "genres": [
#       "Crime",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 108,
#     "metacritic": 60,
#     "rated": "R",
#     "cast": [
#       "John Travolta",
#       "James Gandolfini",
#       "Jared Leto",
#       "Salma Hayek"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIxNGNjZTMtMGM5Ny00MmQ5LWEwODQtYTZkNGY2MjQ1MGM3XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Lonely Hearts",
#     "fullplot": "In the late 1940's, Martha Beck and Raymond Fernandez were America's notorious \"Lonely Hearts Killers\". Their lethal scam was simple; they would swindle and then viciously murder lovelorn war widows who would answer their personal ads in which Ray would describe himself as a sexy Latin Lover. Ironically, Ray's initial introduction to Martha was as a prospective mark. But when they met, it was love at first sight, perhaps as a result of their penchant for kinky sex and their mutual love for duplicity and easy money. With Martha posing as Ray's sister, they bilked elderly spinsters and widows of their savings and then viciously murdered them in a bloodbath of sexual frenzy. When they were arrested, Martha and Ray confessed to 12 killings, although it is believed the actual number is closer to 20. At their sensational trial, Martha and Ray cooed, held hands and seemed as though they could not get enough of each other. Their plea of not guilty by reason of insanity was rejected, and on August 22, 1949, the homicidal lovers were sentenced to death. After numerous appeals, they were electrocuted on March 8, 1951, side-by-side in Sing Sing prison.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2006-10-21T00:00:00Z"
#     },
#     "directors": [
#       "Todd Robinson"
#     ],
#     "writers": [
#       "Todd Robinson"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-28 00:31:01.910000000",
#     "year": 2006,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 16744,
#       "id": 441774
#     },
#     "countries": [
#       "Germany",
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.cstar.com/lonelyhearts/",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 9726,
#         "meter": 49
#       },
#       "dvd": {
#         "$date": "2007-07-31T00:00:00Z"
#       },
#       "critic": {
#         "rating": 5.6,
#         "numReviews": 42,
#         "meter": 48
#       },
#       "boxOffice": "$0.1M",
#       "consensus": "Several genres and plotlines intertwine in Lonely Hearts but don't connect, creating an uneven and unsatisfying film.",
#       "rotten": 22,
#       "production": "Samuel Goldwyn/Roadside",
#       "lastUpdated": {
#         "$date": "2015-08-19T19:12:53Z"
#       },
#       "fresh": 20
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3dccc"
#     },
#     "plot": "The events leading up to the sword fighting cat's meeting with Shrek and his friends.",
#     "genres": [
#       "Animation",
#       "Adventure",
#       "Comedy"
#     ],
#     "runtime": 90,
#     "metacritic": 65,
#     "rated": "PG",
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Zach Galifianakis",
#       "Billy Bob Thornton"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTMxMTU5MTY4MV5BMl5BanBnXkFtZTcwNzgyNjg2NQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Puss in Boots",
#     "fullplot": "Years before meeting Shrek and Donkey, the adorable but tricky Puss in Boots must clear his name from all charges making him a wanted fugitive. While trying to steal magic beans from the infamous criminals Jack and Jill, the hero crosses paths with his female match, Kitty Softpaws, who leads Puss to his old friend, but now enemy, Humpty Dumpty. Memories of friendship and betrayal enlarges Puss' doubt, but he eventually agrees to help the egg get the magic beans. Together, the three plan to steal the beans, get to the Giant's castle, nab the golden goose, and clear Puss' name.",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": "2011-10-28T00:00:00Z"
#     },
#     "directors": [
#       "Chris Miller"
#     ],
#     "writers": [
#       "Charles Perrault (character)",
#       "Tom Wheeler (screenplay)",
#       "Brian Lynch (story)",
#       "William Davies (story)",
#       "Tom Wheeler (story)"
#     ],
#     "awards": {
#       "wins": 7,
#       "nominations": 41,
#       "text": "Nominated for 1 Oscar. Another 6 wins & 41 nominations."
#     },
#     "lastupdated": "2015-08-23 00:38:10.813000000",
#     "year": 2011,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 104860,
#       "id": 448694
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.pussinbootsthemovie.com/",
#       "viewer": {
#         "rating": 3.6,
#         "numReviews": 77938,
#         "meter": 68
#       },
#       "dvd": {
#         "$date": "2012-02-24T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.8,
#         "numReviews": 142,
#         "meter": 84
#       },
#       "boxOffice": "$149.2M",
#       "consensus": "It isn't deep or groundbreaking, but what it lacks in profundity, Puss in Boots more than makes up for with an abundance of wit, visual sparkle, and effervescent charm.",
#       "rotten": 23,
#       "production": "Paramount/Dreamworks",
#       "lastUpdated": {
#         "$date": "2015-09-12T18:19:37Z"
#       },
#       "fresh": 119
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd82d05"
#     },
#     "plot": "Exiled artist and poet Mustafa embarks on a journey home with his housekeeper and her daughter; together the trio must evade the authorities who fear that the truth in Mustafa's words will incite rebellion.",
#     "genres": [
#       "Animation"
#     ],
#     "runtime": 84,
#     "metacritic": 61,
#     "rated": "PG",
#     "cast": [
#       "Salma Hayek",
#       "Liam Neeson",
#       "John Krasinski",
#       "Quvenzhan\u00e8 Wallis"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTY5NzI4MjE2OV5BMl5BanBnXkFtZTgwMDg3OTU5NTE@._V1_SY1000_SX677_AL_.jpg",
#     "title": "The Prophet",
#     "fullplot": "Exiled artist and poet Mustafa embarks on a journey home with his housekeeper and her daughter; together the trio must evade the authorities who fear that the truth in Mustafa's words will incite rebellion.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2015-08-07T00:00:00Z"
#     },
#     "directors": [
#       "Roger Allers",
#       "Ga\u00e8tan Brizzi",
#       "Paul Brizzi",
#       "Joan C. Gratz",
#       "Mohammed Saeed Harib",
#       "Tomm Moore",
#       "Nina Paley",
#       "Bill Plympton",
#       "Joann Sfar",
#       "Michal Socha"
#     ],
#     "writers": [
#       "Roger Allers (screenplay)",
#       "Kahlil Gibran (novel)",
#       "Irene Mecchi (Additional Story & Dialogue)",
#       "Hanna Weg (additional writing)",
#       "Douglas Wood (additional story and dialogue)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 2,
#       "text": "2 nominations."
#     },
#     "lastupdated": "2015-08-29 00:02:18.623000000",
#     "year": 2014,
#     "imdb": {
#       "rating": 6.8,
#       "votes": 618,
#       "id": 1640718
#     },
#     "countries": [
#       "USA",
#       "France",
#       "Canada",
#       "Lebanon",
#       "Qatar"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd833ed"
#     },
#     "plot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Sport"
#     ],
#     "runtime": 105,
#     "metacritic": 40,
#     "rated": "PG",
#     "cast": [
#       "Kevin James",
#       "Salma Hayek",
#       "Henry Winkler",
#       "Greg Germann"
#     ],
#     "num_mflix_comments": 0,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTUxMzEzNDQ0Nl5BMl5BanBnXkFtZTcwMDI2NTY1OA@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Here Comes the Boom",
#     "fullplot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "languages": [
#       "English",
#       "Dutch"
#     ],
#     "released": {
#       "$date": "2012-10-12T00:00:00Z"
#     },
#     "directors": [
#       "Frank Coraci"
#     ],
#     "writers": [
#       "Allan Loeb",
#       "Kevin James"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-09-05 00:38:20.260000000",
#     "year": 2012,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 69939,
#       "id": 1648179
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13cff29313caabd88de0"
#     },
#     "plot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Sport"
#     ],
#     "runtime": 105,
#     "metacritic": 40,
#     "rated": "PG",
#     "cast": [
#       "Kevin James",
#       "Salma Hayek",
#       "Henry Winkler",
#       "Greg Germann"
#     ],
#     "num_mflix_comments": 0,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTUxMzEzNDQ0Nl5BMl5BanBnXkFtZTcwMDI2NTY1OA@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Here Comes the Boom",
#     "fullplot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "languages": [
#       "English",
#       "Dutch"
#     ],
#     "released": {
#       "$date": "2012-10-12T00:00:00Z"
#     },
#     "directors": [
#       "Frank Coraci"
#     ],
#     "writers": [
#       "Allan Loeb",
#       "Kevin James"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-09-12 06:11:27.110000000",
#     "year": 2012,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 70090,
#       "id": 1648179
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13d1f29313caabd8ec00"
#     },
#     "plot": "An out-of-work publicist who suffers an accident looks to sell the exclusive interview rights to the highest bidder in an attempt to provide for his family.",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 94,
#     "metacritic": 32,
#     "cast": [
#       "Jos\u00e8 Mota",
#       "Salma Hayek",
#       "Blanca Portillo",
#       "Juan Luis Galiardo"
#     ],
#     "num_mflix_comments": 0,
#     "poster": "https://m.media-amazon.com/images/M/MV5BNzY4NTEyMjMzOF5BMl5BanBnXkFtZTcwNjEzNzIwOQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "As Luck Would Have It",
#     "fullplot": "An out-of-work publicist who suffers an accident looks to sell the exclusive interview rights to the highest bidder in an attempt to provide for his family.",
#     "languages": [
#       "Spanish"
#     ],
#     "released": {
#       "$date": "2012-01-13T00:00:00Z"
#     },
#     "directors": [
#       "\u00e8lex de la Iglesia"
#     ],
#     "writers": [
#       "Randy Feldman (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-08-08 00:39:36.037000000",
#     "year": 2011,
#     "imdb": {
#       "rating": 6.2,
#       "votes": 1786,
#       "id": 1808240
#     },
#     "countries": [
#       "Spain",
#       "France",
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.ifcfilms.com/films/as-luck-would-have-it",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 302,
#         "meter": 48
#       },
#       "critic": {
#         "rating": 4.6,
#         "numReviews": 5,
#         "meter": 40
#       },
#       "lastUpdated": {
#         "$date": "2015-06-15T18:02:26Z"
#       },
#       "rotten": 3,
#       "production": "Independent Pictures",
#       "fresh": 2
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13e9f29313caabdcc159"
#     },
#     "plot": "The film serves as Garrone's English-language debut and will interweave three separate story strands bookended by brief bits in which Italians Alba Rohrwacher and Massimo Ceccherini will ...",
#     "genres": [
#       "Fantasy",
#       "Romance"
#     ],
#     "runtime": 125,
#     "metacritic": 80,
#     "cast": [
#       "Salma Hayek",
#       "Vincent Cassel",
#       "Toby Jones",
#       "John C. Reilly"
#     ],
#     "num_mflix_comments": 0,
#     "poster": "https://m.media-amazon.com/images/M/MV5BOTBiY2U2MTctNTA4Ni00MDBkLTk5MjItZWUxNDk5YmFlMTliL2ltYWdlXkEyXkFqcGdeQXVyNDUxNjc5NjY@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Tale of Tales",
#     "fullplot": "The film serves as Garrone's English-language debut and will interweave three separate story strands bookended by brief bits in which Italians Alba Rohrwacher and Massimo Ceccherini will play a street circus family. In one tale Salma Hayek will play a jealous queen who forfeits her husband's life. In another, Vincent Cassel plays a king whose passion is stoked by two mysterious sisters.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2015-05-14T00:00:00Z"
#     },
#     "directors": [
#       "Matteo Garrone"
#     ],
#     "writers": [
#       "Giambattista Basile (book)",
#       "Edoardo Albinati (screenplay)",
#       "Ugo Chiti (screenplay)",
#       "Matteo Garrone (screenplay)",
#       "Massimo Gaudioso (screenplay)"
#     ],
#     "awards": {
#       "wins": 3,
#       "nominations": 4,
#       "text": "3 wins & 4 nominations."
#     },
#     "lastupdated": "2015-09-01 00:07:19.663000000",
#     "year": 2015,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 1961,
#       "id": 3278330
#     },
#     "countries": [
#       "Italy",
#       "France",
#       "UK"
#     ],
#     "type": "movie"
#   }
# ]

# %%
# display the titles of movies in which Salma Hayek acted
salma_movies_titles = movies.find({"cast" : "Salma Hayek"})
for movie in salma_movies_titles:
    print(dumps(movie['title'], indent=2))
# Out:
# "Roadracers"
# "Desperado"
# "Fools Rush In"
# "The Hunchback"
# "54"
# "Frida"
# "Wild Wild West"
# "No One Writes to the Colonel"
# "54"
# "In the Time of the Butterflies"
# "Once Upon a Time in Mexico"
# "After the Sunset"
# "Ask the Dust"
# "Lonely Hearts"
# "Puss in Boots"
# "The Prophet"
# "Here Comes the Boom"
# "Here Comes the Boom"
# "As Luck Would Have It"
# "Tale of Tales"

# %%
# display ONLY the titles of movies in which Salma Hayek acted
salma_movies_titles = movies.find({"cast" : "Salma Hayek"})
for movie in salma_movies_titles:
    print(dumps(movie['title'], indent=2))
# Out:
# "Roadracers"
# "Desperado"
# "Fools Rush In"
# "The Hunchback"
# "54"
# "Frida"
# "Wild Wild West"
# "No One Writes to the Colonel"
# "54"
# "In the Time of the Butterflies"
# "Once Upon a Time in Mexico"
# "After the Sunset"
# "Ask the Dust"
# "Lonely Hearts"
# "Puss in Boots"
# "The Prophet"
# "Here Comes the Boom"
# "Here Comes the Boom"
# "As Luck Would Have It"
# "Tale of Tales"

# %% [markdown]
# ### Operations on cusrsor and aggregations
# Documentation for aggregation pipeline:
# - https://www.mongodb.com/docs/manual/core/aggregation-pipeline/
# - https://pymongo.readthedocs.io/en/stable/examples/aggregation.html

# %% [markdown]
# #### Limiting

# %%
limited = movies.find(
{"directors": "Sam Raimi"},
{"_id":0, "title": 1, "cast":1}
).limit(2)
print(dumps(limited, indent=2))
# Out:
# [
#   {
#     "title": "Darkman",
#     "cast": [
#       "Liam Neeson",
#       "Frances McDormand",
#       "Colin Friels",
#       "Larry Drake"
#     ]
#   },
#   {
#     "cast": [
#       "Bruce Campbell",
#       "Embeth Davidtz",
#       "Marcus Gilbert",
#       "Ian Abercrombie"
#     ],
#     "title": "Army of Darkness"
#   }
# ]

# %%
pipeline = [
{"$match" : {"directors": "Sam Raimi"}},
{"$project": {"_id": 0, "title":1, "cast":1}},
{"$limit": 2}
]

# %%
limited_agg = movies.aggregate(pipeline)
print(dumps(limited_agg, indent=2))
# Out:
# [
#   {
#     "title": "Darkman",
#     "cast": [
#       "Liam Neeson",
#       "Frances McDormand",
#       "Colin Friels",
#       "Larry Drake"
#     ]
#   },
#   {
#     "cast": [
#       "Bruce Campbell",
#       "Embeth Davidtz",
#       "Marcus Gilbert",
#       "Ian Abercrombie"
#     ],
#     "title": "Army of Darkness"
#   }
# ]

# %% [markdown]
# #### Sorting

# %%
sorted_cursor = movies.find(
    {"directors": "Sam Raimi"},
    {"_id":0, "year":1, "title":1, "cast": 1}
).sort("year", ASCENDING)
print(dumps(sorted_cursor, indent=2))
# Out:
# [
#   {
#     "year": 1990,
#     "title": "Darkman",
#     "cast": [
#       "Liam Neeson",
#       "Frances McDormand",
#       "Colin Friels",
#       "Larry Drake"
#     ]
#   },
#   {
#     "cast": [
#       "Bruce Campbell",
#       "Embeth Davidtz",
#       "Marcus Gilbert",
#       "Ian Abercrombie"
#     ],
#     "title": "Army of Darkness",
#     "year": 1992
#   },
#   {
#     "cast": [
#       "Sharon Stone",
#       "Gene Hackman",
#       "Russell Crowe",
#       "Leonardo DiCaprio"
#     ],
#     "title": "The Quick and the Dead",
#     "year": 1995
#   },
#   {
#     "cast": [
#       "Bill Paxton",
#       "Bridget Fonda",
#       "Billy Bob Thornton",
#       "Brent Briscoe"
#     ],
#     "title": "A Simple Plan",
#     "year": 1998
#   },
#   {
#     "year": 1999,
#     "title": "For Love of the Game",
#     "cast": [
#       "Kevin Costner",
#       "Kelly Preston",
#       "John C. Reilly",
#       "Jena Malone"
#     ]
#   },
#   {
#     "cast": [
#       "Cate Blanchett",
#       "Giovanni Ribisi",
#       "Keanu Reeves",
#       "Katie Holmes"
#     ],
#     "title": "The Gift",
#     "year": 2000
#   },
#   {
#     "cast": [
#       "Tobey Maguire",
#       "Willem Dafoe",
#       "Kirsten Dunst",
#       "James Franco"
#     ],
#     "title": "Spider-Man",
#     "year": 2002
#   },
#   {
#     "year": 2004,
#     "title": "Spider-Man 2",
#     "cast": [
#       "Tobey Maguire",
#       "Kirsten Dunst",
#       "James Franco",
#       "Alfred Molina"
#     ]
#   },
#   {
#     "year": 2007,
#     "title": "Spider-Man 3",
#     "cast": [
#       "Tobey Maguire",
#       "Kirsten Dunst",
#       "James Franco",
#       "Thomas Haden Church"
#     ]
#   },
#   {
#     "year": 2009,
#     "title": "Drag Me to Hell",
#     "cast": [
#       "Alison Lohman",
#       "Justin Long",
#       "Lorna Raver",
#       "Dileep Rao"
#     ]
#   },
#   {
#     "cast": [
#       "James Franco",
#       "Mila Kunis",
#       "Rachel Weisz",
#       "Michelle Williams"
#     ],
#     "title": "Oz the Great and Powerful",
#     "year": 2013
#   }
# ]

# %%
pipeline = [
{"$match" : {"directors": "Sam Raimi"}},
{"$project": {"_id": 0, "year":1, "title":1, "cast":1}},
{"$sort": {"year": DESCENDING}}
]

# %%
sorted_agg = movies.aggregate(pipeline)
print(dumps(sorted_agg, indent=2))
# Out:
# [
#   {
#     "cast": [
#       "James Franco",
#       "Mila Kunis",
#       "Rachel Weisz",
#       "Michelle Williams"
#     ],
#     "title": "Oz the Great and Powerful",
#     "year": 2013
#   },
#   {
#     "year": 2009,
#     "title": "Drag Me to Hell",
#     "cast": [
#       "Alison Lohman",
#       "Justin Long",
#       "Lorna Raver",
#       "Dileep Rao"
#     ]
#   },
#   {
#     "year": 2007,
#     "title": "Spider-Man 3",
#     "cast": [
#       "Tobey Maguire",
#       "Kirsten Dunst",
#       "James Franco",
#       "Thomas Haden Church"
#     ]
#   },
#   {
#     "year": 2004,
#     "title": "Spider-Man 2",
#     "cast": [
#       "Tobey Maguire",
#       "Kirsten Dunst",
#       "James Franco",
#       "Alfred Molina"
#     ]
#   },
#   {
#     "cast": [
#       "Tobey Maguire",
#       "Willem Dafoe",
#       "Kirsten Dunst",
#       "James Franco"
#     ],
#     "title": "Spider-Man",
#     "year": 2002
#   },
#   {
#     "cast": [
#       "Cate Blanchett",
#       "Giovanni Ribisi",
#       "Keanu Reeves",
#       "Katie Holmes"
#     ],
#     "title": "The Gift",
#     "year": 2000
#   },
#   {
#     "year": 1999,
#     "title": "For Love of the Game",
#     "cast": [
#       "Kevin Costner",
#       "Kelly Preston",
#       "John C. Reilly",
#       "Jena Malone"
#     ]
#   },
#   {
#     "cast": [
#       "Bill Paxton",
#       "Bridget Fonda",
#       "Billy Bob Thornton",
#       "Brent Briscoe"
#     ],
#     "title": "A Simple Plan",
#     "year": 1998
#   },
#   {
#     "cast": [
#       "Sharon Stone",
#       "Gene Hackman",
#       "Russell Crowe",
#       "Leonardo DiCaprio"
#     ],
#     "title": "The Quick and the Dead",
#     "year": 1995
#   },
#   {
#     "cast": [
#       "Bruce Campbell",
#       "Embeth Davidtz",
#       "Marcus Gilbert",
#       "Ian Abercrombie"
#     ],
#     "title": "Army of Darkness",
#     "year": 1992
#   },
#   {
#     "year": 1990,
#     "title": "Darkman",
#     "cast": [
#       "Liam Neeson",
#       "Frances McDormand",
#       "Colin Friels",
#       "Larry Drake"
#     ]
#   }
# ]

# %% [markdown]
# ##### List movies in which Tom Hanks acted sorted by year and title

# %%
tom_hanks_cursor = movies.find({"cast": "Tom Hanks"})
sorted_cursor = tom_hanks_cursor.sort([("year", 1), ("title", 1)])
print(dumps(sorted_cursor, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "573a1398f29313caabce943a"
#     },
#     "plot": "A young man is reunited with a mermaid who saves him from drowning as a boy and falls in love not knowing who/what she is.",
#     "genres": [
#       "Comedy",
#       "Fantasy",
#       "Romance"
#     ],
#     "runtime": 111,
#     "rated": "PG",
#     "cast": [
#       "Tom Hanks",
#       "Daryl Hannah",
#       "Eugene Levy",
#       "John Candy"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BZDRmZTQ0MDQtNWRmYS00NDhhLTgzNzUtZGIyYzkwZDMyNTc0L2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Splash",
#     "fullplot": "Allen Bauer is rescued from drowning as a young boy off Cape Cod by a young mermaid. Years later, he returns to the same location, and once again manages to fall into the sea, and is rescued once more by the mermaid (Allen isn't sure what he has seen and what he has imagined). Using maps from a sunken ship, the mermaid decides to search for Allen in New York City, sprouting legs when her tail dries. On finding Allen, they fall in love, but she has a secret, which will no longer be a secret if she gets her legs wet.",
#     "languages": [
#       "English",
#       "Swedish"
#     ],
#     "released": {
#       "$date": "1984-03-09T00:00:00Z"
#     },
#     "directors": [
#       "Ron Howard"
#     ],
#     "writers": [
#       "Brian Grazer (story)",
#       "Bruce Jay Friedman (screen story)",
#       "Lowell Ganz (screenplay)",
#       "Babaloo Mandel (screenplay)",
#       "Bruce Jay Friedman (screenplay)"
#     ],
#     "awards": {
#       "wins": 4,
#       "nominations": 7,
#       "text": "Nominated for 1 Oscar. Another 3 wins & 7 nominations."
#     },
#     "lastupdated": "2015-08-15 00:27:58.600000000",
#     "year": 1984,
#     "imdb": {
#       "rating": 6.2,
#       "votes": 50482,
#       "id": 88161
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a1398f29313caabcea171"
#     },
#     "plot": "A successful ad man (Hanks) must juggle his ever-demanding career while his parents' marriage breaks up.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 118,
#     "metacritic": 62,
#     "rated": "PG",
#     "cast": [
#       "Tom Hanks",
#       "Jackie Gleason",
#       "Eva Marie Saint",
#       "Hector Elizondo"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BNjhkOTQ4OTctYTkzMi00YTE4LTk4MDItM2NmYjZhNDUzYWM3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Nothing in Common",
#     "fullplot": "David Basner is a successful advertising executive who has it all: Money, happiness, and women who want him. Then one day his world falls apart when his mother leaves his father. Now, he must balance his life between his mother, who is happy with her newfound independence, and his father, a recently laid off salesman who is hard-headed, stubborn, and hides a lot from David. Now David must cope with the downfall of his family and his life.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1986-07-30T00:00:00Z"
#     },
#     "directors": [
#       "Garry Marshall"
#     ],
#     "writers": [
#       "Rick Podell",
#       "Michael Preminger"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-13 00:04:44.613000000",
#     "year": 1986,
#     "imdb": {
#       "rating": 5.9,
#       "votes": 4655,
#       "id": 91653
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a1398f29313caabceacfc"
#     },
#     "plot": "When a boy wishes to be big at a magic wish machine, he wakes up the next morning and finds himself in an adult body.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Fantasy"
#     ],
#     "runtime": 104,
#     "metacritic": 72,
#     "rated": "PG",
#     "cast": [
#       "Tom Hanks",
#       "Elizabeth Perkins",
#       "Robert Loggia",
#       "John Heard"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMDQ1ODM5MTMtMjAwYi00ZGUxLTliNTMtN2ZhODAwMjVhMTRlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Big",
#     "fullplot": "A young boy makes a wish at a carnival machine to be big. He wakes up the following morning to find that it has been granted and his body has grown older overnight. But he is still the same 12-year-old boy inside. Now he must learn how to cope with the unfamiliar world of grown-ups including getting a job and having his first romantic encounter with a woman. What will he find out about this strange world?",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1988-06-03T00:00:00Z"
#     },
#     "directors": [
#       "Penny Marshall"
#     ],
#     "writers": [
#       "Gary Ross",
#       "Anne Spielberg"
#     ],
#     "awards": {
#       "wins": 14,
#       "nominations": 11,
#       "text": "Nominated for 2 Oscars. Another 12 wins & 11 nominations."
#     },
#     "lastupdated": "2015-09-10 17:57:48.333000000",
#     "year": 1988,
#     "imdb": {
#       "rating": 7.3,
#       "votes": 139983,
#       "id": 94737
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.5,
#         "numReviews": 400093,
#         "meter": 82
#       },
#       "dvd": {
#         "$date": "2001-12-18T00:00:00Z"
#       },
#       "critic": {
#         "rating": 7.9,
#         "numReviews": 71,
#         "meter": 97
#       },
#       "lastUpdated": {
#         "$date": "2015-09-14T17:23:17Z"
#       },
#       "consensus": "Refreshingly sweet and undeniably funny, Big is a showcase for Tom Hanks, who dives into his role and infuses it with charm and surprising poignancy.",
#       "rotten": 2,
#       "production": "Twentieth Century Fox Home Entertainment",
#       "fresh": 69
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a1398f29313caabceb175"
#     },
#     "plot": "Steven Gold is a stand-up comedian who is flat broke and has recently dropped out of medical school. He and several others work regularly at the Gas Station, a New York comedy club. The ...",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 128,
#     "rated": "R",
#     "cast": [
#       "Sally Field",
#       "Tom Hanks",
#       "John Goodman",
#       "Mark Rydell"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BNGEwMzFmOWQtMzcyMS00MDYxLTlhZTYtMWI5OWU3ZmU1Mzc0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Punchline",
#     "fullplot": "Steven Gold is a stand-up comedian who is flat broke and has recently dropped out of medical school. He and several others work regularly at the Gas Station, a New York comedy club. The wages are lousy and everybody hopes for the big break. Lilah Krytsick is housewife with an ambition to be a stand-up comedian, however she doesnt seem to have the talent. Steven takes her under his wings and teaches her the art of comedy and humour. But when a TV station arranges a comedy evening at the club, Steve sees his opportunity for fame and stardom. Their friendship seems quickly forgotten and now it's every man and woman for him- or herself!",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1988-10-07T00:00:00Z"
#     },
#     "directors": [
#       "David Seltzer"
#     ],
#     "writers": [
#       "David Seltzer"
#     ],
#     "awards": {
#       "wins": 1,
#       "nominations": 0,
#       "text": "1 win."
#     },
#     "lastupdated": "2015-09-16 00:10:54.440000000",
#     "year": 1988,
#     "imdb": {
#       "rating": 5.8,
#       "votes": 6256,
#       "id": 95927
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 7180,
#         "meter": 42
#       },
#       "dvd": {
#         "$date": "2002-07-09T00:00:00Z"
#       },
#       "critic": {
#         "rating": 5.4,
#         "numReviews": 16,
#         "meter": 50
#       },
#       "lastUpdated": {
#         "$date": "2015-07-22T18:58:04Z"
#       },
#       "rotten": 8,
#       "production": "Sony Pictures Home Entertainment",
#       "fresh": 8
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a1398f29313caabceb467"
#     },
#     "plot": "An overstressed suburbanite and his paramilitaric neighbor struggle to prove their paranoid theory that the new family in town is a front for a cannibalistic cult.",
#     "genres": [
#       "Comedy",
#       "Mystery"
#     ],
#     "runtime": 101,
#     "rated": "PG",
#     "cast": [
#       "Tom Hanks",
#       "Bruce Dern",
#       "Carrie Fisher",
#       "Rick Ducommun"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BNWE1OGExYzQtYzRjOS00MmJhLWE3OTYtZjkzOTNlMjJlZTQ4L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyODY0NzcxNw@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "The 'Burbs",
#     "fullplot": "This story takes place in a typical American neighborhood, when some new neighbors come to live in the house next to Ray Peterson. These new people are really strange; nobody has ever seen them, their house is a real mess, and during the night you can hear weird noises from their basement. The only thing they know is their name: Klopeks. One day Walter (an old man of the neighborhood) suddenly disappears and everyone starts to suspect the Klopeks...",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1989-02-17T00:00:00Z"
#     },
#     "directors": [
#       "Joe Dante"
#     ],
#     "writers": [
#       "Dana Olsen"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-09-05 00:34:06.330000000",
#     "year": 1989,
#     "imdb": {
#       "rating": 6.8,
#       "votes": 47459,
#       "id": 96734
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.3,
#         "numReviews": 60075,
#         "meter": 72
#       },
#       "dvd": {
#         "$date": "1999-05-04T00:00:00Z"
#       },
#       "critic": {
#         "rating": 5.4,
#         "numReviews": 15,
#         "meter": 47
#       },
#       "lastUpdated": {
#         "$date": "2015-08-20T18:47:49Z"
#       },
#       "rotten": 8,
#       "production": "MCA Universal Home Video",
#       "fresh": 7
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a1398f29313caabcebb20"
#     },
#     "plot": "A detective must adopt the dog of a dead man to help him find the murderer.",
#     "genres": [
#       "Comedy",
#       "Crime",
#       "Drama"
#     ],
#     "runtime": 97,
#     "rated": "PG",
#     "cast": [
#       "Tom Hanks",
#       "Mare Winningham",
#       "Craig T. Nelson",
#       "Reginald VelJohnson"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMGYxNjdjMTItMmUwYy00NzNhLTk1NjctZWVkZTMzZTYzNjBmXkEyXkFqcGdeQXVyNzc5MjA3OA@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Turner & Hooch",
#     "fullplot": "Scott Turner has 3 days left in the local police department before he moves to a bigger city to get some \"real\" cases, not just misdemeanors. Then Amos Reed is murdered, and Scott Turner sets himself on the case. The closest thing to a witness in the case is Amos Reed's dog, Hooch, which Scott Turner has to take care of if it's going to avoid being \"put to sleep\".",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1989-07-28T00:00:00Z"
#     },
#     "directors": [
#       "Roger Spottiswoode"
#     ],
#     "writers": [
#       "Dennis Shryack (story)",
#       "Michael Blodgett (story)",
#       "Dennis Shryack (screenplay)",
#       "Michael Blodgett (screenplay)",
#       "Daniel Petrie Jr. (screenplay)",
#       "Jim Cash (screenplay)",
#       "Jack Epps Jr. (screenplay)"
#     ],
#     "awards": {
#       "wins": 1,
#       "nominations": 1,
#       "text": "1 win & 1 nomination."
#     },
#     "lastupdated": "2015-09-17 04:45:50.173000000",
#     "year": 1989,
#     "imdb": {
#       "rating": 6.0,
#       "votes": 43848,
#       "id": 98536
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.0,
#         "numReviews": 189560,
#         "meter": 52
#       },
#       "dvd": {
#         "$date": "2002-04-02T00:00:00Z"
#       },
#       "critic": {
#         "rating": 5.3,
#         "numReviews": 28,
#         "meter": 54
#       },
#       "lastUpdated": {
#         "$date": "2015-09-17T18:18:13Z"
#       },
#       "rotten": 13,
#       "production": "Buena Vista Pictures",
#       "fresh": 15
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a1398f29313caabcebd8d"
#     },
#     "plot": "After his mistress runs over a young teen, a Wall Street hotshot sees his life unravel in the spotlight, and attracting the interest of a down and out reporter.",
#     "genres": [
#       "Comedy",
#       "Drama"
#     ],
#     "runtime": 125,
#     "rated": "R",
#     "cast": [
#       "Tom Hanks",
#       "Bruce Willis",
#       "Melanie Griffith",
#       "Kim Cattrall"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTc4MzEzMjc0Nl5BMl5BanBnXkFtZTgwNzU1NTk4NjE@._V1_SY1000_SX677_AL_.jpg",
#     "title": "The Bonfire of the Vanities",
#     "fullplot": "Financial \"Master of the Universe\" Sherman McCoy sees his life unravel when his mistress Maria Ruskin hits a black boy with his car. When yellow journalist Peter Fallow enflames public opinion with a series of distorted tabloid articles on the accident, the case is seized upon by opportunists like Reverend Bacon and mayoral candidate D.A. Abe Weiss.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1990-12-21T00:00:00Z"
#     },
#     "directors": [
#       "Brian De Palma"
#     ],
#     "writers": [
#       "Michael Cristofer (screenplay)",
#       "Tom Wolfe (novel)"
#     ],
#     "awards": {
#       "wins": 1,
#       "nominations": 5,
#       "text": "1 win & 5 nominations."
#     },
#     "lastupdated": "2015-08-30 00:43:37.993000000",
#     "year": 1990,
#     "imdb": {
#       "rating": 5.4,
#       "votes": 16807,
#       "id": 99165
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 2.6,
#         "numReviews": 11988,
#         "meter": 27
#       },
#       "dvd": {
#         "$date": "2001-11-06T00:00:00Z"
#       },
#       "critic": {
#         "rating": 3.9,
#         "numReviews": 50,
#         "meter": 16
#       },
#       "lastUpdated": {
#         "$date": "2015-08-22T19:22:00Z"
#       },
#       "rotten": 42,
#       "production": "Warner Home Video",
#       "fresh": 8
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabced287"
#     },
#     "fullplot": "During World War II when all the men are fighting the war, most of the jobs that were left vacant because of their absence were filled in by women. The owners of the baseball teams, not wanting baseball to be dormant indefinitely, decide to form teams with women. So scouts are sent all over the country to find women players. One of the scouts, passes through Oregon and finds a woman named Dottie Hinson, who is incredible. He approaches her and asks her to try out but she's not interested. However, her sister, Kit who wants to get out of Oregon, offers to go. But he agrees only if she can get her sister to go. When they try out, they're chosen and are on the same team. Jimmy Dugan, a former player, who's now a drunk, is the team manager. But he doesn't feel as if it's a real job so he drinks and is not exactly doing his job. So Dottie steps up. After a few months when it appears the girls are not garnering any attention, the league is facing closure till Dottie does something that grabs attention. And it isn't long Dottie is the star of the team and Kit feels like she's living in her shadow.",
#     "imdb": {
#       "rating": 7.2,
#       "votes": 66350,
#       "id": 104694
#     },
#     "year": 1992,
#     "plot": "Two sisters join the first female professional baseball league and struggle to help it succeed amidst their own growing rivalry.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Sport"
#     ],
#     "rated": "PG",
#     "metacritic": 67,
#     "title": "A League of Their Own",
#     "lastupdated": "2015-09-07 00:06:58.937000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Kim Wilson (story)",
#       "Kelly Candaele (story)",
#       "Lowell Ganz (screenplay)",
#       "Babaloo Mandel (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.4,
#         "numReviews": 365832,
#         "meter": 84
#       },
#       "dvd": {
#         "$date": "1997-09-09T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.7,
#         "numReviews": 57,
#         "meter": 77
#       },
#       "lastUpdated": {
#         "$date": "2015-08-19T18:22:55Z"
#       },
#       "consensus": "Sentimental and light, but still thoroughly charming, A League of Their Own is buoyed by solid performances from a wonderful cast.",
#       "rotten": 13,
#       "production": "Columbia Pictures",
#       "fresh": 44
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BNjQ1NTQyYjktZDc5My00NDA1LWI1NmItY2ViNjQ0NDk4NmRjXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 2,
#     "released": {
#       "$date": "1992-07-01T00:00:00Z"
#     },
#     "awards": {
#       "wins": 8,
#       "nominations": 5,
#       "text": "Nominated for 2 Golden Globes. Another 6 wins & 5 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Geena Davis",
#       "Lori Petty",
#       "Madonna"
#     ],
#     "directors": [
#       "Penny Marshall"
#     ],
#     "runtime": 128
#   },
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabcede5b"
#     },
#     "plot": "When a man with AIDS is fired by his law firm because of his condition, he hires a homophobic small time lawyer as the only willing advocate for a wrongful dismissal suit.",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 125,
#     "metacritic": 66,
#     "rated": "PG-13",
#     "cast": [
#       "Tom Hanks",
#       "Denzel Washington",
#       "Roberta Maxwell",
#       "Buzz Kilman"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BNDE0MWE1ZTMtOWFkMS00YjdiLTkwZTItMDljYjY3MjM0NTk5XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Philadelphia",
#     "fullplot": "Andrew Beckett, a gay lawyer infected with AIDS, is fired from his law firm in fear that they might contract AIDS from him. After Andrew is fired, in a last attempt for peace, he sues his former law firm with the help of a homophobic lawyer, Joe Miller. During the court battle, Miller sees that Beckett is no different than anyone else on the gritty streets of the city of brotherly love, sheds his homophobia and helps Beckett with his case before AIDS overcomes him.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1994-01-14T00:00:00Z"
#     },
#     "directors": [
#       "Jonathan Demme"
#     ],
#     "writers": [
#       "Ron Nyswaner"
#     ],
#     "awards": {
#       "wins": 13,
#       "nominations": 14,
#       "text": "Won 2 Oscars. Another 11 wins & 14 nominations."
#     },
#     "lastupdated": "2015-09-04 00:33:51.383000000",
#     "year": 1993,
#     "imdb": {
#       "rating": 7.7,
#       "votes": 166994,
#       "id": 107818
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.7,
#         "numReviews": 182037,
#         "meter": 89
#       },
#       "dvd": {
#         "$date": "1997-09-09T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.6,
#         "numReviews": 50,
#         "meter": 78
#       },
#       "lastUpdated": {
#         "$date": "2015-09-13T17:05:10Z"
#       },
#       "consensus": "Philadelphia indulges in some unfortunate clich\u00e8s in its quest to impart a meaningful message, but its stellar cast and sensitive direction are more than enough to compensate.",
#       "rotten": 11,
#       "production": "Sony Pictures Home Entertainment",
#       "fresh": 39
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabcedfae"
#     },
#     "fullplot": "After his wife Maggie passes away, Sam Baldwin and his 8-year-old son Jonah relocate from Chicago to Seattle to escape the grief associated with Maggie's death. Eighteen months later Sam is still grieving and can't sleep. Although Jonah misses his mother, he wants his father to get a new wife despite Sam having not even contemplated dating again. On Christmas Eve, Sam (on Jonah's initiative) ends up pouring his heart out on a national radio talk show about his magical and perfect marriage to Maggie, and how much he still misses her. Among the many women who hear Sam's story and fall in love with him solely because of it is Annie Reed, a Baltimore-based newspaper writer. Annie's infatuation with Sam's story and by association Sam himself is despite being already engaged. But Annie's relationship with her straight-laced fianc\u00e8 Walter is unlike her dream love life in the movie An Affair to Remember (1957). She even writes to Sam proposing they meet atop the Empire State Building on Valentine's Day. Back in Seattle, Sam has received hundreds of letters from women wanting to meet him. Jonah is excited by one letter in particular from Baltimore and will do whatever he needs to to get his father and Annie together. However, old fashioned Sam wants his future love life to be based on meeting a woman the traditional way and he, in turn, becomes infatuated with an unknown woman he spots a few times in Seattle. Will magic happen twice in Sam's life, and if so will it be with this unknown woman or Annie?",
#     "imdb": {
#       "rating": 6.8,
#       "votes": 113432,
#       "id": 108160
#     },
#     "year": 1993,
#     "plot": "A recently widowed man's son calls a radio talk-show in an attempt to find his father a partner.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "rated": "PG",
#     "metacritic": 72,
#     "title": "Sleepless in Seattle",
#     "lastupdated": "2015-09-05 00:24:06.330000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Jeff Arch (story)",
#       "Nora Ephron (screenplay)",
#       "David S. Ward (screenplay)",
#       "Jeff Arch (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.3,
#         "numReviews": 296344,
#         "meter": 75
#       },
#       "dvd": {
#         "$date": "1997-06-26T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.5,
#         "numReviews": 46,
#         "meter": 72
#       },
#       "lastUpdated": {
#         "$date": "2015-09-14T18:27:28Z"
#       },
#       "rotten": 13,
#       "production": "TriStar Pictures",
#       "fresh": 33
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BNWY1MDJkZGUtZTE2OS00ODZiLTlmNzQtMDZjNzM2ZjkwM2QxXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 0,
#     "released": {
#       "$date": "1993-06-25T00:00:00Z"
#     },
#     "awards": {
#       "wins": 6,
#       "nominations": 11,
#       "text": "Nominated for 2 Oscars. Another 4 wins & 11 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Ross Malinger",
#       "Rita Wilson",
#       "Victor Garber"
#     ],
#     "directors": [
#       "Nora Ephron"
#     ],
#     "runtime": 105
#   },
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabcee607"
#     },
#     "fullplot": "Forrest Gump is a simple man with a low I.Q. but good intentions. He is running through childhood with his best and only friend Jenny. His 'mama' teaches him the ways of life and leaves him to choose his destiny. Forrest joins the army for service in Vietnam, finding new friends called Dan and Bubba, he wins medals, creates a famous shrimp fishing fleet, inspires people to jog, starts a ping-pong craze, create the smiley, write bumper stickers and songs, donating to people and meeting the president several times. However, this is all irrelevant to Forrest who can only think of his childhood sweetheart Jenny Curran. Who has messed up her life. Although in the end all he wants to prove is that anyone can love anyone.",
#     "imdb": {
#       "rating": 8.8,
#       "votes": 1087227,
#       "id": 109830
#     },
#     "year": 1994,
#     "plot": "Forrest Gump, while not intelligent, has accidentally been present at many historic moments, but his true love, Jenny Curran, eludes him.",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "rated": "PG-13",
#     "metacritic": 82,
#     "title": "Forrest Gump",
#     "lastupdated": "2015-08-22 00:15:05.593000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Winston Groom (novel)",
#       "Eric Roth (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.paramount.com/movies/forrest-gump/",
#       "viewer": {
#         "rating": 4.1,
#         "numReviews": 1238843,
#         "meter": 95
#       },
#       "dvd": {
#         "$date": "2001-08-28T00:00:00Z"
#       },
#       "critic": {
#         "rating": 7.2,
#         "numReviews": 81,
#         "meter": 72
#       },
#       "boxOffice": "$0.4M",
#       "consensus": "Forrest Gump may be an overly sentimental film with a somewhat problematic message, but its sweetness and charm are usually enough to approximate true depth and grace.",
#       "rotten": 23,
#       "production": "Paramount Pictures",
#       "lastUpdated": {
#         "$date": "2015-09-12T18:18:31Z"
#       },
#       "fresh": 58
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 136,
#     "released": {
#       "$date": "1994-07-06T00:00:00Z"
#     },
#     "awards": {
#       "wins": 46,
#       "nominations": 47,
#       "text": "Won 6 Oscars. Another 40 wins & 47 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Rebecca Williams",
#       "Sally Field",
#       "Michael Conner Humphreys"
#     ],
#     "directors": [
#       "Robert Zemeckis"
#     ],
#     "runtime": 142
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabceefa7"
#     },
#     "fullplot": "Based on the true story of the ill-fated 13th Apollo mission bound for the moon. Astronauts Lovell, Haise and Swigert were scheduled to fly Apollo 14, but are moved up to 13. It's 1970, and America have already achieved their lunar landing goal, so there's little interest in this \"routine\" flight.. until that is, things go very wrong, and prospects of a safe return fade.",
#     "imdb": {
#       "rating": 7.6,
#       "votes": 193096,
#       "id": 112384
#     },
#     "year": 1995,
#     "plot": "NASA must devise a strategy to return Apollo 13 to Earth safely after the spacecraft undergoes massive internal damage putting the lives of the three astronauts on board in jeopardy.",
#     "genres": [
#       "Adventure",
#       "Drama",
#       "History"
#     ],
#     "rated": "PG",
#     "metacritic": 77,
#     "title": "Apollo 13",
#     "lastupdated": "2015-09-05 00:34:38.597000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Jim Lovell (book)",
#       "Jeffrey Kluger (book)",
#       "William Broyles Jr. (screenplay)",
#       "Al Reinert (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.imax.com/apollo13",
#       "viewer": {
#         "rating": 3.6,
#         "numReviews": 430746,
#         "meter": 86
#       },
#       "dvd": {
#         "$date": "2004-09-07T00:00:00Z"
#       },
#       "critic": {
#         "rating": 8.2,
#         "numReviews": 85,
#         "meter": 95
#       },
#       "boxOffice": "$1.1M",
#       "consensus": "In recreating the troubled space mission, Apollo 13 pulls no punches: it's a masterfully told drama from director Ron Howard, bolstered by an ensemble of solid performances.",
#       "rotten": 4,
#       "production": "Universal Pictures",
#       "lastUpdated": {
#         "$date": "2015-09-13T09:51:48Z"
#       },
#       "fresh": 81
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BNjEzYjJmNzgtNDkwNy00MTQ4LTlmMWMtNzA4YjE2NjI0ZDg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 0,
#     "released": {
#       "$date": "1995-06-30T00:00:00Z"
#     },
#     "awards": {
#       "wins": 34,
#       "nominations": 38,
#       "text": "Won 2 Oscars. Another 32 wins & 38 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Bill Paxton",
#       "Kevin Bacon",
#       "Gary Sinise"
#     ],
#     "directors": [
#       "Ron Howard"
#     ],
#     "runtime": 140
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef887"
#     },
#     "fullplot": "A little boy named Andy loves to be in his room, playing with his toys, especially his doll named \"Woody\". But, what do the toys do when Andy is not with them, they come to life. Woody believes that he has life (as a toy) good. However, he must worry about Andy's family moving, and what Woody does not know is about Andy's birthday party. Woody does not realize that Andy's mother gave him an action figure known as Buzz Lightyear, who does not believe that he is a toy, and quickly becomes Andy's new favorite toy. Woody, who is now consumed with jealousy, tries to get rid of Buzz. Then, both Woody and Buzz are now lost. They must find a way to get back to Andy before he moves without them, but they will have to pass through a ruthless toy killer, Sid Phillips.",
#     "imdb": {
#       "rating": 8.3,
#       "votes": 542659,
#       "id": 114709
#     },
#     "year": 1995,
#     "plot": "A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room.",
#     "genres": [
#       "Animation",
#       "Adventure",
#       "Comedy"
#     ],
#     "rated": "G",
#     "metacritic": 92,
#     "title": "Toy Story",
#     "lastupdated": "2015-08-31 00:06:17.687000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "John Lasseter (original story by)",
#       "Pete Docter (original story by)",
#       "Andrew Stanton (original story by)",
#       "Joe Ranft (original story by)",
#       "Joss Whedon (screenplay)",
#       "Andrew Stanton (screenplay)",
#       "Joel Cohen (screenplay)",
#       "Alec Sokolow (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.disney.com/ToyStory",
#       "viewer": {
#         "rating": 3.7,
#         "numReviews": 1103788,
#         "meter": 92
#       },
#       "dvd": {
#         "$date": "2001-03-20T00:00:00Z"
#       },
#       "critic": {
#         "rating": 9.0,
#         "numReviews": 78,
#         "meter": 100
#       },
#       "lastUpdated": {
#         "$date": "2015-09-12T18:12:39Z"
#       },
#       "consensus": "Entertaining as it is innovative, Toy Story reinvigorated animation while heralding the arrival of Pixar as a family-friendly force to be reckoned with.",
#       "rotten": 0,
#       "production": "Buena Vista",
#       "fresh": 78
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 131,
#     "released": {
#       "$date": "1995-11-22T00:00:00Z"
#     },
#     "awards": {
#       "wins": 26,
#       "nominations": 14,
#       "text": "Nominated for 3 Oscars. Another 23 wins & 14 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Tim Allen",
#       "Don Rickles",
#       "Jim Varney"
#     ],
#     "directors": [
#       "John Lasseter"
#     ],
#     "runtime": 81
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0e5c"
#     },
#     "plot": "Dramatized portrayal of the Apollo manned space program.",
#     "genres": [
#       "Action",
#       "Drama",
#       "History"
#     ],
#     "runtime": 60,
#     "cast": [
#       "Tom Hanks",
#       "Nick Searcy",
#       "Lane Smith",
#       "David Andrews"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTg1NTM4ODctMWUxYi00NDZhLWJhNGEtNzA3MGE4MWY4N2E2XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg",
#     "title": "From the Earth to the Moon",
#     "fullplot": "Through dramatization, this series relates the story of the conquest of the moon by the Americans, from the Mercury and Gemini projects to the legendary Apollo missions.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "1998-04-05T00:00:00Z"
#     },
#     "awards": {
#       "wins": 22,
#       "nominations": 32,
#       "text": "Won 1 Golden Globe. Another 21 wins & 32 nominations."
#     },
#     "lastupdated": "2015-09-01 00:03:01.520000000",
#     "year": 1998,
#     "imdb": {
#       "rating": 8.9,
#       "votes": 6929,
#       "id": 120570
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "series",
#     "tomatoes": {
#       "viewer": {
#         "rating": 4.0,
#         "numReviews": 50,
#         "meter": 100
#       },
#       "dvd": {
#         "$date": "2004-04-13T00:00:00Z"
#       },
#       "lastUpdated": {
#         "$date": "2015-09-10T19:09:51Z"
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0f16"
#     },
#     "fullplot": "Opening with the Allied invasion of Normandy on 6 June 1944, members of the 2nd Ranger Battalion under Cpt. Miller fight ashore to secure a beachhead. Amidst the fighting, two brothers are killed in action. Earlier in New Guinea, a third brother is KIA. Their mother, Mrs. Ryan, is to receive all three of the grave telegrams on the same day. The United States Army Chief of Staff, George C. Marshall, is given an opportunity to alleviate some of her grief when he learns of a fourth brother, Private James Ryan, and decides to send out 8 men (Cpt. Miller and select members from 2nd Rangers) to find him and bring him back home to his mother...",
#     "imdb": {
#       "rating": 8.6,
#       "votes": 775637,
#       "id": 120815
#     },
#     "year": 1998,
#     "plot": "Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.",
#     "genres": [
#       "Action",
#       "Drama",
#       "War"
#     ],
#     "rated": "R",
#     "metacritic": 90,
#     "title": "Saving Private Ryan",
#     "lastupdated": "2015-08-22 00:00:15.437000000",
#     "languages": [
#       "English",
#       "French",
#       "German",
#       "Czech"
#     ],
#     "writers": [
#       "Robert Rodat"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://https://www.facebook.com/SavingPrivateRyanMovie",
#       "viewer": {
#         "rating": 4.0,
#         "numReviews": 988034,
#         "meter": 95
#       },
#       "dvd": {
#         "$date": "1999-11-02T00:00:00Z"
#       },
#       "critic": {
#         "rating": 8.6,
#         "numReviews": 130,
#         "meter": 92
#       },
#       "lastUpdated": {
#         "$date": "2015-09-12T17:31:13Z"
#       },
#       "consensus": "Anchored by another winning performance from Tom Hanks, Steven Spielberg's unflinchingly realistic war film virtually redefines the genre.",
#       "rotten": 10,
#       "production": "Paramount Pictures",
#       "fresh": 120
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 144,
#     "released": {
#       "$date": "1998-07-24T00:00:00Z"
#     },
#     "awards": {
#       "wins": 83,
#       "nominations": 66,
#       "text": "Won 5 Oscars. Another 78 wins & 66 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Tom Sizemore",
#       "Edward Burns",
#       "Barry Pepper"
#     ],
#     "directors": [
#       "Steven Spielberg"
#     ],
#     "runtime": 169
#   },
#   {
#     "_id": {
#       "$oid": "573a139bf29313caabcf2d10"
#     },
#     "fullplot": "The owner of a large bookstore chain starts putting the owner of a small local bookstore out of business. Meanwhile they have been corresponding over the internet without knowing who either of them are. They can't stand each other in person but over the internet they are very attracted. He finds out who she is but she doesn't know. He starts to like her more but she still hates him. He has to fix it.",
#     "imdb": {
#       "rating": 6.5,
#       "votes": 139830,
#       "id": 128853
#     },
#     "year": 1998,
#     "plot": "Two business rivals hate each other at the office but fall in love over the internet.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "rated": "PG",
#     "metacritic": 57,
#     "title": "You've Got Mail",
#     "lastupdated": "2015-09-07 00:17:22.163000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Mikl\u00e8s L\u00e8szl\u00e8 (play)",
#       "Nora Ephron (screenplay)",
#       "Delia Ephron (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.youvegotmail.com",
#       "viewer": {
#         "rating": 3.1,
#         "numReviews": 461550,
#         "meter": 73
#       },
#       "dvd": {
#         "$date": "1999-05-04T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.2,
#         "numReviews": 83,
#         "meter": 69
#       },
#       "lastUpdated": {
#         "$date": "2015-09-16T17:47:27Z"
#       },
#       "consensus": "Great chemistry between the leads made this a warm and charming delight.",
#       "rotten": 26,
#       "production": "Warner Bros. Pictures",
#       "fresh": 57
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BZTcxNzgzZjMtYzZiZC00MmE1LTg3MzQtZDAxMTYyZWE4MDNhL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 0,
#     "released": {
#       "$date": "1998-12-18T00:00:00Z"
#     },
#     "awards": {
#       "wins": 6,
#       "nominations": 7,
#       "text": "Nominated for 1 Golden Globe. Another 5 wins & 7 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Meg Ryan",
#       "Greg Kinnear",
#       "Parker Posey"
#     ],
#     "directors": [
#       "Nora Ephron"
#     ],
#     "runtime": 119
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0eae"
#     },
#     "fullplot": "Death Row guards at a penitentiary, in the 1930's, have a moral dilemma with their job when they discover one of their prisoners, a convicted murderer, has a special gift.",
#     "imdb": {
#       "rating": 8.5,
#       "votes": 681825,
#       "id": 120689
#     },
#     "year": 1999,
#     "plot": "The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.",
#     "genres": [
#       "Crime",
#       "Drama",
#       "Fantasy"
#     ],
#     "rated": "R",
#     "metacritic": 61,
#     "title": "The Green Mile",
#     "lastupdated": "2015-08-31 00:33:33.090000000",
#     "languages": [
#       "English",
#       "French"
#     ],
#     "writers": [
#       "Stephen King (novel)",
#       "Frank Darabont (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.thegreenmile.com",
#       "viewer": {
#         "rating": 4.1,
#         "numReviews": 810219,
#         "meter": 94
#       },
#       "dvd": {
#         "$date": "2000-06-13T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.8,
#         "numReviews": 132,
#         "meter": 80
#       },
#       "lastUpdated": {
#         "$date": "2015-09-12T17:52:45Z"
#       },
#       "consensus": "Though The Green Mile is long, critics say it's an absorbing, emotionally powerful experience.",
#       "rotten": 27,
#       "production": "Warner Bros. Pictures",
#       "fresh": 105
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 144,
#     "released": {
#       "$date": "1999-12-10T00:00:00Z"
#     },
#     "awards": {
#       "wins": 19,
#       "nominations": 26,
#       "text": "Nominated for 4 Oscars. Another 15 wins & 26 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "David Morse",
#       "Michael Clarke Duncan",
#       "Bonnie Hunt"
#     ],
#     "directors": [
#       "Frank Darabont"
#     ],
#     "runtime": 189
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0d8b"
#     },
#     "fullplot": "While Andy is away at summer camp Woody has been toynapped by Al McWiggin, a greedy collector and proprietor of \"Al's Toy Barn\"! In this all-out rescue mission, Buzz and his friends Mr. Potato Head, Slinky Dog, Rex and Hamm springs into action to rescue Woody from winding up as a museum piece. They must find a way to save him before he gets sold in Japan forever and they'll never see him again!",
#     "imdb": {
#       "rating": 7.9,
#       "votes": 346655,
#       "id": 120363
#     },
#     "year": 1999,
#     "plot": "When Woody is stolen by a toy collector, Buzz and his friends vow to rescue him, but Woody finds the idea of immortality in a museum tempting.",
#     "genres": [
#       "Animation",
#       "Adventure",
#       "Comedy"
#     ],
#     "rated": "G",
#     "metacritic": 88,
#     "title": "Toy Story 2",
#     "lastupdated": "2015-09-07 00:06:19.897000000",
#     "languages": [
#       "English",
#       "Arabic",
#       "Spanish"
#     ],
#     "writers": [
#       "John Lasseter (original story by)",
#       "Pete Docter (original story by)",
#       "Ash Brannon (original story by)",
#       "Andrew Stanton (original story by)",
#       "Andrew Stanton (screenplay)",
#       "Rita Hsiao (screenplay)",
#       "Doug Chamberlin (screenplay)",
#       "Chris Webb (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://disney.go.com/toystory/",
#       "viewer": {
#         "rating": 3.5,
#         "numReviews": 994797,
#         "meter": 86
#       },
#       "dvd": {
#         "$date": "2000-10-17T00:00:00Z"
#       },
#       "critic": {
#         "rating": 8.6,
#         "numReviews": 163,
#         "meter": 100
#       },
#       "lastUpdated": {
#         "$date": "2015-09-12T18:02:14Z"
#       },
#       "consensus": "The rare sequel that arguably improves on its predecessor, Toy Story 2 uses inventive storytelling, gorgeous animation, and a talented cast to deliver another rich moviegoing experience for all ages.",
#       "rotten": 0,
#       "production": "Buena Vista Pictures",
#       "fresh": 163
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BMWM5ZDcxMTYtNTEyNS00MDRkLWI3YTItNThmMGExMWY4NDIwXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 150,
#     "released": {
#       "$date": "1999-11-24T00:00:00Z"
#     },
#     "awards": {
#       "wins": 22,
#       "nominations": 24,
#       "text": "Nominated for 1 Oscar. Another 21 wins & 24 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Tim Allen",
#       "Joan Cusack",
#       "Kelsey Grammer"
#     ],
#     "directors": [
#       "John Lasseter",
#       "Ash Brannon",
#       "Lee Unkrich"
#     ],
#     "runtime": 92
#   },
#   {
#     "_id": {
#       "$oid": "573a13a4f29313caabd0f756"
#     },
#     "plot": "Produced by Steven Spielberg and presented by Tom Hanks this documentary tells how war photographers faced the horrors that looked both in Europe and in the Pacific during World War II .",
#     "genres": [
#       "Documentary"
#     ],
#     "runtime": 88,
#     "cast": [
#       "Tom Hanks",
#       "Stephen Ambrose",
#       "Russ Meyer",
#       "Walter Rosenblum"
#     ],
#     "title": "Shooting War",
#     "fullplot": "Produced by Steven Spielberg and presented by Tom Hanks this documentary tells how war photographers faced the horrors that looked both in Europe and in the Pacific during World War II .",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2000-12-07T00:00:00Z"
#     },
#     "directors": [
#       "Richard Schickel"
#     ],
#     "writers": [
#       "Richard Schickel"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 2,
#       "text": "Nominated for 1 Primetime Emmy. Another 1 nomination."
#     },
#     "lastupdated": "2015-09-17 04:42:02.380000000",
#     "year": 2000,
#     "imdb": {
#       "rating": 7.9,
#       "votes": 361,
#       "id": 250730
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.9,
#         "numReviews": 7032,
#         "meter": 84
#       },
#       "lastUpdated": {
#         "$date": "2015-06-08T18:11:55Z"
#       }
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a13a4f29313caabd12b44"
#     },
#     "fullplot": "An FBI agent hunts down a young con artist who successfully impersonated an airline pilot, doctor, and assistant attorney general, cashing more than $2.5 million in fraudulent checks in 26 countries.",
#     "imdb": {
#       "rating": 8.0,
#       "votes": 438892,
#       "id": 264464
#     },
#     "year": 2002,
#     "plot": "A true story about Frank Abagnale Jr., who, before his 19th birthday, successfully conned millions of dollars' worth of checks as a Pan Am pilot, doctor, and legal prosecutor.",
#     "genres": [
#       "Biography",
#       "Crime",
#       "Drama"
#     ],
#     "rated": "PG-13",
#     "metacritic": 76,
#     "title": "Catch Me If You Can",
#     "lastupdated": "2015-09-03 00:48:03.617000000",
#     "languages": [
#       "English",
#       "French"
#     ],
#     "writers": [
#       "Jeff Nathanson (screenplay)",
#       "Frank Abagnale Jr. (book)",
#       "Stan Redding (book)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.dreamworks.com/catchthem/jump2.html",
#       "viewer": {
#         "rating": 3.6,
#         "numReviews": 744160,
#         "meter": 89
#       },
#       "dvd": {
#         "$date": "2003-05-06T00:00:00Z"
#       },
#       "critic": {
#         "rating": 7.9,
#         "numReviews": 194,
#         "meter": 96
#       },
#       "boxOffice": "$164.4M",
#       "consensus": "With help from a strong performance by Leonardo DiCaprio as real-life wunderkind con artist Frank Abagnale, Steven Spielberg crafts a film that's stylish, breezily entertaining, and surprisingly sweet.",
#       "rotten": 8,
#       "production": "DreamWorks SKG",
#       "lastUpdated": {
#         "$date": "2015-09-12T17:25:13Z"
#       },
#       "fresh": 186
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTY5MzYzNjc5NV5BMl5BanBnXkFtZTYwNTUyNTc2._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 132,
#     "released": {
#       "$date": "2002-12-25T00:00:00Z"
#     },
#     "awards": {
#       "wins": 15,
#       "nominations": 27,
#       "text": "Nominated for 2 Oscars. Another 13 wins & 27 nominations."
#     },
#     "countries": [
#       "USA",
#       "Canada"
#     ],
#     "cast": [
#       "Leonardo DiCaprio",
#       "Tom Hanks",
#       "Christopher Walken",
#       "Martin Sheen"
#     ],
#     "directors": [
#       "Steven Spielberg"
#     ],
#     "runtime": 141
#   },
#   {
#     "_id": {
#       "$oid": "573a13aaf29313caabd235d8"
#     },
#     "plot": "An eccentric, if not charming Southern professor and his crew pose as a classical ensemble in order to rob a casino, all under the nose of his unsuspecting but sharp old landlady.",
#     "genres": [
#       "Comedy",
#       "Crime",
#       "Thriller"
#     ],
#     "runtime": 104,
#     "metacritic": 56,
#     "rated": "R",
#     "cast": [
#       "Tom Hanks",
#       "Irma P. Hall",
#       "Marlon Wayans",
#       "J.K. Simmons"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTYwNjUxMTYzM15BMl5BanBnXkFtZTYwNjgwMjY3._V1_SY1000_SX677_AL_.jpg",
#     "title": "The Ladykillers",
#     "fullplot": "A remake of the 1955 comedy, the story revolves around a Southern professor who puts together a group of thieves to rob a casino. They rent a room in an old woman's house, but soon she discovers the plot and they must kill her, a task that is more difficult than it seems.",
#     "languages": [
#       "English",
#       "Vietnamese"
#     ],
#     "released": {
#       "$date": "2004-03-26T00:00:00Z"
#     },
#     "directors": [
#       "Ethan Coen",
#       "Joel Coen"
#     ],
#     "writers": [
#       "Joel Coen (screenplay)",
#       "Ethan Coen (screenplay)",
#       "William Rose (movie \"The Ladykillers\")"
#     ],
#     "awards": {
#       "wins": 4,
#       "nominations": 4,
#       "text": "4 wins & 4 nominations."
#     },
#     "lastupdated": "2015-09-16 11:49:52.547000000",
#     "year": 2004,
#     "imdb": {
#       "rating": 6.2,
#       "votes": 78646,
#       "id": 335245
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://ladykillers.movies.go.com",
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 65117,
#         "meter": 43
#       },
#       "dvd": {
#         "$date": "2004-09-07T00:00:00Z"
#       },
# ...
#     },
#     "plot": "After losing his job, a middle-aged man reinvents himself by going back to college.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 98,
#     "metacritic": 41,
#     "rated": "PG-13",
#     "cast": [
#       "Tom Hanks",
#       "Sarah Mahoney",
#       "Roxana Ortega",
#       "Randall Park"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BYjQ4MzlmZDUtN2ViMi00ZTAwLWFkMmItNGRlZmM1NjQ1ZmJjXkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Larry Crowne",
#     "fullplot": "Until he was downsized, affable, amiable Larry Crowne (Hanks) was a superstar team leader at the big-box company where he's worked since his time in the Navy. Underwater on his mortgage and unclear on what to do with his suddenly free days, Larry heads to his local college to start over. There he becomes part of a colorful community of outcasts, also-rans and the overlooked all trying to find a better future for themselves...often moving around town in a herd of scooters. In his public-speaking class, Larry develops an unexpected crush on his teacher Mercedes Tainot (Roberts), who has lost as much passion for teaching as she has for her husband. The simple guy who has every reason to think his life has stalled will come to learn an unexpected lesson: when you think everything worth having has passed you by, you just might discover your reason to live.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2011-07-01T00:00:00Z"
#     },
#     "directors": [
#       "Tom Hanks"
#     ],
#     "writers": [
#       "Tom Hanks",
#       "Nia Vardalos"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-08-28 00:07:09.160000000",
#     "year": 2011,
#     "imdb": {
#       "rating": 6.0,
#       "votes": 44944,
#       "id": 1583420
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a13c5f29313caabd6eb4e"
#     },
#     "fullplot": "Everything is connected: an 1849 diary of an ocean voyage across the Pacific; letters from a composer to his lover; a thriller about a conspiracy at a nuclear power plant; a farce about a publisher in a nursing home; a rebellious clone in futuristic Korea; and the tale of a tribe living in post-apocalyptic Seoul, far in the future.",
#     "imdb": {
#       "rating": 7.5,
#       "votes": 263527,
#       "id": 1371111
#     },
#     "year": 2012,
#     "plot": "An exploration of how the actions of individual lives impact one another in the past, present and future, as one soul is shaped from a killer into a hero, and an act of kindness ripples across centuries to inspire a revolution.",
#     "genres": [
#       "Drama",
#       "Sci-Fi"
#     ],
#     "rated": "R",
#     "metacritic": 55,
#     "title": "Cloud Atlas",
#     "lastupdated": "2015-09-02 00:14:02.693000000",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "writers": [
#       "David Mitchell (novel)",
#       "Lana Wachowski (written for the screen by)",
#       "Tom Tykwer (written for the screen by)",
#       "Andy Wachowski (written for the screen by)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.cloudatlasmovie.com",
#       "viewer": {
#         "rating": 3.6,
#         "numReviews": 185779,
#         "meter": 66
#       },
#       "dvd": {
#         "$date": "2013-05-14T00:00:00Z"
#       },
#       "critic": {
#         "rating": 6.6,
#         "numReviews": 253,
#         "meter": 66
#       },
#       "boxOffice": "$27.1M",
#       "consensus": "Its sprawling, ambitious blend of thought-provoking narrative and eye-catching visuals will prove too unwieldy for some, but the sheer size and scope of Cloud Atlas are all but impossible to ignore.",
#       "rotten": 86,
#       "production": "Warner Bros. Pictures",
#       "lastUpdated": {
#         "$date": "2015-09-12T18:23:08Z"
#       },
#       "fresh": 167
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTczMTgxMjc4NF5BMl5BanBnXkFtZTcwNjM5MTA2OA@@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 0,
#     "released": {
#       "$date": "2012-10-26T00:00:00Z"
#     },
#     "awards": {
#       "wins": 17,
#       "nominations": 65,
#       "text": "Nominated for 1 Golden Globe. Another 16 wins & 65 nominations."
#     },
#     "countries": [
#       "Germany",
#       "USA",
#       "Hong Kong",
#       "Singapore"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Halle Berry",
#       "Jim Broadbent",
#       "Hugo Weaving"
#     ],
#     "directors": [
#       "Tom Tykwer",
#       "Andy Wachowski",
#       "Lana Wachowski"
#     ],
#     "runtime": 172
#   },
#   {
#     "_id": {
#       "$oid": "573a13c9f29313caabd7a6ee"
#     },
#     "fullplot": "Captain Phillips is a multi-layered examination of the 2009 hijacking of the U.S. container ship Maersk Alabama by a crew of Somali pirates. It is - through director Paul Greengrass's distinctive lens - simultaneously a pulse-pounding thriller, and a complex portrait of the myriad effects of globalization. The film focuses on the relationship between the Alabama's commanding officer, Captain Richard Phillips (two time Academy Award\u00e8-winner Tom Hanks), and the Somali pirate captain, Muse (Barkhad Abdi), who takes him hostage. Phillips and Muse are set on an unstoppable collision course when Muse and his crew target Phillips' unarmed ship; in the ensuing standoff, 145 miles off the Somali coast, both men will find themselves at the mercy of forces beyond their control.",
#     "imdb": {
#       "rating": 7.9,
#       "votes": 292910,
#       "id": 1535109
#     },
#     "year": 2013,
#     "plot": "The true story of Captain Richard Phillips and the 2009 hijacking by Somali pirates of the US-flagged MV Maersk Alabama, the first American cargo ship to be hijacked in two hundred years.",
#     "genres": [
#       "Biography",
#       "Drama",
#       "Thriller"
#     ],
#     "rated": "PG-13",
#     "metacritic": 83,
#     "title": "Captain Phillips",
#     "lastupdated": "2015-08-24 00:10:33.337000000",
#     "languages": [
#       "English",
#       "Somali"
#     ],
#     "writers": [
#       "Billy Ray (screenplay)",
#       "Richard Phillips (based upon the book \"A Captain's Duty: Somali Pirates",
#       " Navy SEALS",
#       " and Dangerous Days at Sea\" by)",
#       "Stephan Talty (based upon the book \"A Captain's Duty: Somali Pirates",
#       " Navy SEALS",
#       " and Dangerous Days at Sea\" by)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.captainphillipsmovie.com/",
#       "viewer": {
#         "rating": 4.2,
#         "numReviews": 149185,
#         "meter": 89
#       },
#       "dvd": {
#         "$date": "2014-01-21T00:00:00Z"
#       },
#       "critic": {
#         "rating": 8.3,
#         "numReviews": 238,
#         "meter": 93
#       },
#       "boxOffice": "$107.1M",
#       "consensus": "Smart, powerfully acted, and incredibly intense, Captain Phillips offers filmgoers a Hollywood biopic done right -- and offers Tom Hanks a showcase for yet another brilliant performance.",
#       "rotten": 16,
#       "production": "Sony Pictures",
#       "lastUpdated": {
#         "$date": "2015-08-20T18:05:10Z"
#       },
#       "fresh": 222
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BODhiZWRhMjctNDUyMS00NmUwLTgwYmItMjJhOWNkZWQ3ZTQxXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 0,
#     "released": {
#       "$date": "2013-10-11T00:00:00Z"
#     },
#     "awards": {
#       "wins": 27,
#       "nominations": 125,
#       "text": "Nominated for 6 Oscars. Another 21 wins & 125 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Tom Hanks",
#       "Catherine Keener",
#       "Barkhad Abdi",
#       "Barkhad Abdirahman"
#     ],
#     "directors": [
#       "Paul Greengrass"
#     ],
#     "runtime": 134
#   },
#   {
#     "_id": {
#       "$oid": "573a13daf29313caabdac620"
#     },
#     "plot": "Based on The New York Times best-selling novel, Killing Lincoln is the suspenseful, eye-opening story of the events surrounding the assassination of U.S. President Abraham Lincoln.",
#     "genres": [
#       "Biography",
#       "Drama",
#       "History"
#     ],
#     "runtime": 92,
#     "cast": [
#       "Tom Hanks",
#       "Regen Wilson",
#       "Billy Campbell",
#       "Jesse Johnson"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMjMyNDYyNzk4NV5BMl5BanBnXkFtZTgwMDAxNzA2MDE@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Killing Lincoln",
#     "fullplot": "Based on The New York Times best-selling novel, Killing Lincoln is the suspenseful, eye-opening story of the events surrounding the assassination of U.S. President Abraham Lincoln.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2013-02-17T00:00:00Z"
#     },
#     "directors": [
#       "Adrian Moat"
#     ],
#     "writers": [
#       "Erik Jendresen",
#       "Bill O'Reilly (based on the book by)",
#       "Martin Dugard (book)"
#     ],
#     "awards": {
#       "wins": 5,
#       "nominations": 5,
#       "text": "Nominated for 3 Primetime Emmys. Another 2 wins & 5 nominations."
#     },
#     "lastupdated": "2015-08-18 00:00:43.907000000",
#     "year": 2013,
#     "imdb": {
#       "rating": 6.8,
#       "votes": 1595,
#       "id": 2299248
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 0.0,
#         "numReviews": 0
#       },
#       "lastUpdated": {
#         "$date": "2014-10-09T12:53:38Z"
#       }
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a13d7f29313caabda31b0"
#     },
#     "plot": "Author P.L. Travers reflects on her childhood after reluctantly meeting with Walt Disney, who seeks to adapt her Mary Poppins books for the big screen.",
#     "genres": [
#       "Biography",
#       "Comedy",
#       "Drama"
#     ],
#     "runtime": 125,
#     "metacritic": 65,
#     "rated": "PG-13",
#     "cast": [
#       "Emma Thompson",
#       "Tom Hanks",
#       "Annie Rose Buckley",
#       "Colin Farrell"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTc0MTQ3NzE4Nl5BMl5BanBnXkFtZTcwMzA4NDM5OQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Saving Mr. Banks",
#     "fullplot": "When Walt Disney's daughters begged him to make a movie of their favorite book, P.L. Travers' Mary Poppins (1964), he made them a promise - one that he didn't realize would take 20 years to keep. In his quest to obtain the rights, Walt comes up against a curmudgeonly, uncompromising writer who has absolutely no intention of letting her beloved magical nanny get mauled by the Hollywood machine. But, as the books stop selling and money grows short, Travers reluctantly agrees to go to Los Angeles to hear Disney's plans for the adaptation. For those two short weeks in 1961, Walt Disney pulls out all the stops. Armed with imaginative storyboards and chirpy songs from the talented Sherman brothers, Walt launches an all-out onslaught on P.L. Travers, but the prickly author doesn't budge. He soon begins to watch helplessly as Travers becomes increasingly immovable and the rights begin to move further away from his grasp. It is only when he reaches into his own childhood that Walt discovers the truth about the ghosts that haunt her, and together they set Mary Poppins free to ultimately make one of the most endearing films in cinematic history.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2013-12-20T00:00:00Z"
#     },
#     "directors": [
#       "John Lee Hancock"
#     ],
#     "writers": [
#       "Kelly Marcel",
#       "Sue Smith"
#     ],
#     "awards": {
#       "wins": 12,
#       "nominations": 71,
#       "text": "Nominated for 1 Oscar. Another 11 wins & 71 nominations."
#     },
#     "lastupdated": "2015-08-24 00:24:34.180000000",
#     "year": 2013,
#     "imdb": {
#       "rating": 7.5,
#       "votes": 103416,
#       "id": 2140373
#     },
#     "countries": [
#       "UK",
#       "Australia",
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://movies.disney.com/saving-mr-banks/",
#       "viewer": {
#         "rating": 4.0,
#         "numReviews": 110031,
#         "meter": 84
#       },
#       "dvd": {
#         "$date": "2014-03-18T00:00:00Z"
#       },
#       "critic": {
#         "rating": 7.0,
#         "numReviews": 231,
#         "meter": 79
#       },
#       "boxOffice": "$83.3M",
#       "consensus": "Aggressively likable and sentimental to a fault, Saving Mr. Banks pays tribute to the Disney legacy with excellent performances and sweet, high-spirited charm.",
#       "rotten": 48,
#       "production": "Walt Disney Pictures",
#       "lastUpdated": {
#         "$date": "2015-09-15T17:08:13Z"
#       },
#       "fresh": 183
#     },
#     "num_mflix_comments": 0
#   },
#   {
#     "_id": {
#       "$oid": "573a13ddf29313caabdb4773"
#     },
#     "plot": "Woody and the gang are held up at a roadside motel and members of the group start to disappear from everywhere. Woody and set about getting to the bottom of the mystery.",
#     "genres": [
#       "Animation",
#       "Short",
#       "Adventure"
#     ],
#     "runtime": 22,
#     "rated": "TV-G",
#     "cast": [
#       "Tom Hanks",
#       "Tim Allen",
#       "Joan Cusack",
#       "Carl Weathers"
#     ],
#     "num_mflix_comments": 0,
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTZkY2JjMDItYzEwMS00MjVlLTlhYjktMmI5YjYzMjdmZGMxXkEyXkFqcGdeQXVyNDIwODAwNzg@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Toy Story of Terror",
#     "fullplot": "The toys go on a road trip, when an unexpected event leads them to a roadside motel, after one of the toys goes missing, the others find themselves caught up in a mysterious, monstrous, and terrifying sequence of events that must be solved before they all suffer the same fate",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2013-10-16T00:00:00Z"
#     },
#     "directors": [
#       "Angus MacLane"
#     ],
#     "writers": [
#       "Angus MacLane",
#       "Andrew Stanton (characters)",
#       "John Lasseter (characters)"
#     ],
#     "awards": {
#       "wins": 6,
#       "nominations": 10,
#       "text": "6 wins & 10 nominations."
#     },
#     "lastupdated": "2015-08-19 00:05:46.297000000",
#     "year": 2013,
#     "imdb": {
#       "rating": 7.6,
#       "votes": 7342,
#       "id": 2446040
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 4.1,
#         "numReviews": 2282,
#         "meter": 84
#       },
#       "dvd": {
#         "$date": "2014-08-19T00:00:00Z"
#       },
#       "critic": {
#         "rating": 8.6,
#         "numReviews": 13,
#         "meter": 92
#       },
#       "lastUpdated": {
#         "$date": "2015-09-10T19:43:40Z"
#       },
#       "rotten": 1,
#       "production": "Disney Pixar",
#       "fresh": 12
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13ecf29313caabdd2280"
#     },
#     "plot": "It's a post Christmas play date and the toys have to go up against the fearsome and aggressive new dino toys.",
#     "genres": [
#       "Animation",
#       "Short",
#       "Adventure"
#     ],
#     "runtime": 22,
#     "rated": "TV-G",
#     "cast": [
#       "Tom Hanks",
#       "Tim Allen",
#       "Kristen Schaal",
#       "Kevin McKidd"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BOTc2OTA1MDM4M15BMl5BanBnXkFtZTgwNjczMDk5MjE@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Toy Story That Time Forgot",
#     "fullplot": "The story takes place after a Christmas holiday with the regular toys finding themselves trapped in unusual territory with a group of new and delusional action figures. Together they must find their way back to their child's bedroom and to safety.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": "2014-12-02T00:00:00Z"
#     },
#     "directors": [
#       "Steve Purcell"
#     ],
#     "writers": [
#       "Steve Purcell"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 7,
#       "text": "7 nominations."
#     },
#     "lastupdated": "2015-08-20 00:16:11.313000000",
#     "year": 2014,
#     "imdb": {
#       "rating": 7.3,
#       "votes": 2931,
#       "id": 3473654
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "num_mflix_comments": 0
#   }
# ]

# %%
pipeline = [
    {"$match" : {"cast": "Tom Hanks"}},
    {"$project": {"_id": 0, "year":1, "title":1, "cast":1}},
    {"$sort": {"year": -1, "title": -1}}
     ]

sorted_agg = movies.aggregate(pipeline)

for sort in sorted_agg :
    print(dumps(sorted_agg, indent=2))
# Out:
# [
#   {
#     "cast": [
#       "Tom Hanks",
#       "Tim Allen",
#       "Joan Cusack",
#       "Carl Weathers"
#     ],
#     "title": "Toy Story of Terror",
#     "year": 2013
#   },
#   {
#     "cast": [
#       "Emma Thompson",
#       "Tom Hanks",
#       "Annie Rose Buckley",
#       "Colin Farrell"
#     ],
#     "title": "Saving Mr. Banks",
#     "year": 2013
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Regen Wilson",
#       "Billy Campbell",
#       "Jesse Johnson"
#     ],
#     "title": "Killing Lincoln",
#     "year": 2013
#   },
#   {
#     "year": 2013,
#     "title": "Captain Phillips",
#     "cast": [
#       "Tom Hanks",
#       "Catherine Keener",
#       "Barkhad Abdi",
#       "Barkhad Abdirahman"
#     ]
#   },
#   {
#     "year": 2012,
#     "title": "Cloud Atlas",
#     "cast": [
#       "Tom Hanks",
#       "Halle Berry",
#       "Jim Broadbent",
#       "Hugo Weaving"
#     ]
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Sarah Mahoney",
#       "Roxana Ortega",
#       "Randall Park"
#     ],
#     "title": "Larry Crowne",
#     "year": 2011
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Thomas Horn",
#       "Sandra Bullock",
#       "Zoe Caldwell"
#     ],
#     "title": "Extremely Loud & Incredibly Close",
#     "year": 2011
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Tim Allen",
#       "Joan Cusack",
#       "Ned Beatty"
#     ],
#     "title": "Toy Story 3",
#     "year": 2010
#   },
#   {
#     "year": 2009,
#     "title": "Angels & Demons",
#     "cast": [
#       "Tom Hanks",
#       "Ewan McGregor",
#       "Ayelet Zurer",
#       "Stellan Skarsg\u00e8rd"
#     ]
#   },
#   {
#     "cast": [
#       "Keith David",
#       "Katharine Phillips",
#       "Tom Hanks",
#       "Paul Fussell"
#     ],
#     "title": "The War",
#     "year": 2007
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Amy Adams",
#       "Julia Roberts",
#       "Philip Seymour Hoffman"
#     ],
#     "title": "Charlie Wilson's War",
#     "year": 2007
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Audrey Tautou",
#       "Ian McKellen",
#       "Jean Reno"
#     ],
#     "title": "The Da Vinci Code",
#     "year": 2006
#   },
#   {
#     "year": 2004,
#     "title": "The Terminal",
#     "cast": [
#       "Tom Hanks",
#       "Catherine Zeta-Jones",
#       "Stanley Tucci",
#       "Chi McBride"
#     ]
#   },
#   {
#     "year": 2004,
#     "title": "The Terminal",
#     "cast": [
#       "Tom Hanks",
#       "Catherine Zeta-Jones",
#       "Stanley Tucci",
#       "Chi McBride"
#     ]
#   },
#   {
#     "year": 2004,
#     "title": "The Polar Express",
#     "cast": [
#       "Tom Hanks",
#       "Leslie Zemeckis",
#       "Eddie Deezen",
#       "Nona Gaye"
#     ]
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Irma P. Hall",
#       "Marlon Wayans",
#       "J.K. Simmons"
#     ],
#     "title": "The Ladykillers",
#     "year": 2004
#   },
#   {
#     "year": 2002,
#     "title": "Catch Me If You Can",
#     "cast": [
#       "Leonardo DiCaprio",
#       "Tom Hanks",
#       "Christopher Walken",
#       "Martin Sheen"
#     ]
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Stephen Ambrose",
#       "Russ Meyer",
#       "Walter Rosenblum"
#     ],
#     "title": "Shooting War",
#     "year": 2000
#   },
#   {
#     "year": 1999,
#     "title": "Toy Story 2",
#     "cast": [
#       "Tom Hanks",
#       "Tim Allen",
#       "Joan Cusack",
#       "Kelsey Grammer"
#     ]
#   },
#   {
#     "year": 1999,
#     "title": "The Green Mile",
#     "cast": [
#       "Tom Hanks",
#       "David Morse",
#       "Michael Clarke Duncan",
#       "Bonnie Hunt"
#     ]
#   },
#   {
#     "year": 1998,
#     "title": "You've Got Mail",
#     "cast": [
#       "Tom Hanks",
#       "Meg Ryan",
#       "Greg Kinnear",
#       "Parker Posey"
#     ]
#   },
#   {
#     "year": 1998,
#     "title": "Saving Private Ryan",
#     "cast": [
#       "Tom Hanks",
#       "Tom Sizemore",
#       "Edward Burns",
#       "Barry Pepper"
#     ]
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Nick Searcy",
#       "Lane Smith",
#       "David Andrews"
#     ],
#     "title": "From the Earth to the Moon",
#     "year": 1998
#   },
#   {
#     "year": 1995,
#     "title": "Toy Story",
#     "cast": [
#       "Tom Hanks",
#       "Tim Allen",
#       "Don Rickles",
#       "Jim Varney"
#     ]
#   },
#   {
#     "year": 1995,
#     "title": "Apollo 13",
#     "cast": [
#       "Tom Hanks",
#       "Bill Paxton",
#       "Kevin Bacon",
#       "Gary Sinise"
#     ]
#   },
#   {
#     "year": 1994,
#     "title": "Forrest Gump",
#     "cast": [
#       "Tom Hanks",
#       "Rebecca Williams",
#       "Sally Field",
#       "Michael Conner Humphreys"
#     ]
#   },
#   {
#     "year": 1993,
#     "title": "Sleepless in Seattle",
#     "cast": [
#       "Tom Hanks",
#       "Ross Malinger",
#       "Rita Wilson",
#       "Victor Garber"
#     ]
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Denzel Washington",
#       "Roberta Maxwell",
#       "Buzz Kilman"
#     ],
#     "title": "Philadelphia",
#     "year": 1993
#   },
#   {
#     "year": 1992,
#     "title": "A League of Their Own",
#     "cast": [
#       "Tom Hanks",
#       "Geena Davis",
#       "Lori Petty",
#       "Madonna"
#     ]
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Bruce Willis",
#       "Melanie Griffith",
#       "Kim Cattrall"
#     ],
#     "title": "The Bonfire of the Vanities",
#     "year": 1990
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Mare Winningham",
#       "Craig T. Nelson",
#       "Reginald VelJohnson"
#     ],
#     "title": "Turner & Hooch",
#     "year": 1989
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Bruce Dern",
#       "Carrie Fisher",
#       "Rick Ducommun"
#     ],
#     "title": "The 'Burbs",
#     "year": 1989
#   },
#   {
#     "cast": [
#       "Sally Field",
#       "Tom Hanks",
#       "John Goodman",
#       "Mark Rydell"
#     ],
#     "title": "Punchline",
#     "year": 1988
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Elizabeth Perkins",
#       "Robert Loggia",
#       "John Heard"
#     ],
#     "title": "Big",
#     "year": 1988
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Jackie Gleason",
#       "Eva Marie Saint",
#       "Hector Elizondo"
#     ],
#     "title": "Nothing in Common",
#     "year": 1986
#   },
#   {
#     "cast": [
#       "Tom Hanks",
#       "Daryl Hannah",
#       "Eugene Levy",
#       "John Candy"
#     ],
#     "title": "Splash",
#     "year": 1984
#   }
# ]

# %% [markdown]
# #### Skipping

# %%
#count the number of documents in which Sam Raimi acted
pipeline = [
    {"$match": {"directors": "Sam Raimi"}},
    {"$count": "num_movies"}
]
aggregation = movies.aggregate(pipeline)
print(dumps(aggregation,indent=2))
# Out:
# [
#   {
#     "num_movies": 11
#   }
# ]

# %% [markdown]
# ##### Skip records and take only the last one

# %%
skipped = movies.find({"directors": "Sam Raimi"},{"_id": 0, "title":1, "cast":1}).skip(12)
print(dumps(skipped, indent=2))
# Out:
# []

# %% [markdown]
# ##### Skip records and take only the 3 last ones

# %%
skipped_sorted = movies.find({"directors": "Sam Raimi"},{"_id": 0, "title":1, "cast":1}).sort("year").skip(10)
print(dumps(skipped_sorted, indent=2))
# Out:
# [
#   {
#     "cast": [
#       "James Franco",
#       "Mila Kunis",
#       "Rachel Weisz",
#       "Michelle Williams"
#     ],
#     "title": "Oz the Great and Powerful"
#   }
# ]

# %%
pipeline = [
{"$match": {"directors": "Sam Raimi"}},
{"$project": {"_id":0, "year":1, "title":1,"cast":1}},
{"$sort": {"year": ASCENDING}},
{"$skip": 10}]

sorted_skipped_agg = movies.aggregate(pipeline)
print(dumps(sorted_skipped_agg, indent=2))
# Out:
# [
#   {
#     "cast": [
#       "James Franco",
#       "Mila Kunis",
#       "Rachel Weisz",
#       "Michelle Williams"
#     ],
#     "title": "Oz the Great and Powerful",
#     "year": 2013
#   }
# ]
